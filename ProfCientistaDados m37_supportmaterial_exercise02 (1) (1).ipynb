# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Tarefa II
#
# Neste projeto, estamos construindo um credit scoring para cartão de crédito, em um desenho amostral com 15 safras, e utilizando 12 meses de performance.
#
# Carregue a base de dados ```credit_scoring.ftr```.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from scipy.stats import t
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn import metrics
from scipy.stats import ks_2samp
from sklearn.metrics import roc_curve
from pycaret.classification import *
import warnings
from sklearn.decomposition import PCA
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline

# %%
def IV(variavel, resposta):
    tab = pd.crosstab(variavel, resposta, margins=True, margins_name='total')

    rótulo_evento = tab.columns[0]
    rótulo_nao_evento = tab.columns[1]

    tab['pct_evento'] = tab[rótulo_evento]/tab.loc['total',rótulo_evento]
    tab['ep'] = tab[rótulo_evento]/tab.loc['total',rótulo_evento]
    
    tab['pct_nao_evento'] = tab[rótulo_nao_evento]/tab.loc['total',rótulo_nao_evento]
    tab['woe'] = np.log(tab.pct_evento/tab.pct_nao_evento)
    tab['iv_parcial'] = (tab.pct_evento - tab.pct_nao_evento)*tab.woe
    return tab['iv_parcial'].sum()

# %%
def biv_discreta(var, df):
    df['bom'] = 1-df.mau
    g = df.groupby(var)

    biv = pd.DataFrame({'qt_bom': g['bom'].sum(),
                        'qt_mau': g['mau'].sum(),
                        'mau':g['mau'].mean(), 
                        var: g['mau'].mean().index, 
                        'cont':g[var].count()})
    
    biv['ep'] = (biv.mau*(1-biv.mau)/biv.cont)**.5
    biv['mau_sup'] = biv.mau+t.ppf([0.975], biv.cont-1)*biv.ep
    biv['mau_inf'] = biv.mau+t.ppf([0.025], biv.cont-1)*biv.ep
    
    biv['logit'] = np.log(biv.mau/(1-biv.mau))
    biv['logit_sup'] = np.log(biv.mau_sup/(1-biv.mau_sup))
    biv['logit_inf'] = np.log(biv.mau_inf/(1-biv.mau_inf))

    tx_mau_geral = df.mau.mean()
    woe_geral = np.log(df.mau.mean() / (1 - df.mau.mean()))

    biv['woe'] = biv.logit - woe_geral
    biv['woe_sup'] = biv.logit_sup - woe_geral
    biv['woe_inf'] = biv.logit_inf - woe_geral

    fig, ax = plt.subplots(2,1, figsize=(8,6))
    ax[0].plot(biv[var], biv.woe, ':bo', label='woe')
    ax[0].plot(biv[var], biv.woe_sup, 'o:r', label='limite superior')
    ax[0].plot(biv[var], biv.woe_inf, 'o:r', label='limite inferior')
    
    num_cat = biv.shape[0]
    ax[0].set_xlim([-.3, num_cat-.7])

    ax[0].set_ylabel("Weight of Evidence")
    ax[0].legend(bbox_to_anchor=(.83, 1.17), ncol=3)
    
    ax[0].set_xticks(list(range(num_cat)))
    ax[0].set_xticklabels(biv[var], rotation=8)
    
    ax[1] = biv.cont.plot.bar()
    return biv

# %%
def biv_continua(var, ncat, df):
    df['bom'] = 1-df.mau
    cat_srs, bins = pd.qcut(df[var], ncat, retbins=True, precision=0, duplicates='drop')
    g = df.groupby(cat_srs)

    biv = pd.DataFrame({'qt_bom': g['bom'].sum(),
                        'qt_mau': g['mau'].sum(),
                        'mau':g['mau'].mean(), 
                        var: g[var].mean(), 
                        'cont':g[var].count()})
    
    biv['ep'] = (biv.mau*(1-biv.mau)/biv.cont)**.5
    biv['mau_sup'] = biv.mau+t.ppf([0.975], biv.cont-1)*biv.ep
    biv['mau_inf'] = biv.mau+t.ppf([0.025], biv.cont-1)*biv.ep
    
    biv['logit'] = np.log(biv.mau/(1-biv.mau))
    biv['logit_sup'] = np.log(biv.mau_sup/(1-biv.mau_sup))
    biv['logit_inf'] = np.log(biv.mau_inf/(1-biv.mau_inf))

    tx_mau_geral = df.mau.mean()
    woe_geral = np.log(df.mau.mean() / (1 - df.mau.mean()))

    biv['woe'] = biv.logit - woe_geral
    biv['woe_sup'] = biv.logit_sup - woe_geral
    biv['woe_inf'] = biv.logit_inf - woe_geral

    fig, ax = plt.subplots(2,1, figsize=(8,6))
    ax[0].plot(biv[var], biv.woe, ':bo', label='woe')
    ax[0].plot(biv[var], biv.woe_sup, 'o:r', label='limite superior')
    ax[0].plot(biv[var], biv.woe_inf, 'o:r', label='limite inferior')
    
    num_cat = biv.shape[0]

    ax[0].set_ylabel("Weight of Evidence")
    ax[0].legend(bbox_to_anchor=(.83, 1.17), ncol=3)
    
    ax[1] = biv.cont.plot.bar()
    return None

# %%
df = pd.read_feather('credit_scoring.ftr')
df.head(2)
# Out:
#     data_ref  index sexo posse_de_veiculo posse_de_imovel  qtd_filhos  \
# 0 2015-01-01   5733    F                N               N           0
# 1 2015-01-01    727    F                S               S           0
#
#     tipo_renda educacao estado_civil tipo_residencia  idade  tempo_emprego  \
# 0   Empresário    Médio     Solteiro            Casa     43       6.873973
# 1  Assalariado    Médio       Casado            Casa     35       4.526027
#
#    qt_pessoas_residencia    renda    mau
# 0                    1.0  2515.39  False
# 1                    2.0  3180.19  False

# %% [markdown]
# ## Amostragem
#
# Separe os três últimos meses como safras de validação *out of time* (oot).
#
# Variáveis:<br>
# Considere que a variável ```data_ref``` não é uma variável explicativa, é somente uma variável indicadora da safra, e não deve ser utilizada na modelagem. A variávei ```index``` é um identificador do cliente, e também não deve ser utilizada como covariável (variável explicativa). As restantes podem ser utilizadas para prever a inadimplência, incluindo a renda.

# %%
' + '.join(list(df.columns))
# Out:
# 'data_ref + index + sexo + posse_de_veiculo + posse_de_imovel + qtd_filhos + tipo_renda + educacao + estado_civil + tipo_residencia + idade + tempo_emprego + qt_pessoas_residencia + renda + mau'

# %%
df.set_index('data_ref', inplace = True)

df_train = df['2015-01-01':'2015-12-01']
df_test = df['2016-01-01':]

# %%
df_train.reset_index(inplace=True)
df_test.reset_index(inplace=True)

# %%
df_train['Mes'] = df_train['data_ref'].dt.month
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Descritiva básica univariada
#
# - Descreva a base quanto ao número de linhas, número de linhas para cada mês em ```data_ref```.
# - Faça uma descritiva básica univariada de cada variável. Considere as naturezas diferentes: qualitativas e quantitativas.

# %%
fig, ax = plt.subplots(figsize=(13,7))
sns.countplot(data=df_train, x='Mes', palette='mako', ax=ax)
ax.set_title('Número de linhas para cada mês da base de treino')
# Out:
# Text(0.5, 1.0, 'Número de linhas para cada mês da base de treino')

# %%
fig, ax = plt.subplots(nrows=4, ncols=2, figsize=(15,26))

sns.countplot(data=df_train, x='sexo', palette='mako', ax=ax[0,0])
ax[0,0].set_title('Quantidade de clientes do sexo feminino e masculino')

sns.countplot(data=df_train, x='posse_de_veiculo', palette='mako', ax=ax[0,1])
ax[0,1].set_title('Quantidade de clientes que possuem e não possuem veículo')

sns.countplot(data=df_train, x='posse_de_imovel', palette='mako', ax=ax[1,0])
ax[1,0].set_title('Quantidade de clientes que possuem e não possuem imóvel')

sns.countplot(data=df_train, x='mau', palette='mako', ax=ax[1,1])
ax[1,1].set_title('Quantidade de clientes que são e não são mau pagadores')

sns.countplot(data=df_train, x='tipo_renda', palette='mako', ax=ax[2,0])
ax[2,0].set_title('Quantidade de clientes por tipo de renda')

sns.countplot(data=df_train, x='educacao', palette='mako', ax=ax[2,1])
ax[2,1].set_title('Quantidade de clientes por educação')
for tick in ax[2,1].get_xticklabels():
    tick.set_rotation(7)

sns.countplot(data=df_train, x='estado_civil', palette='mako', ax=ax[3,0])
ax[3,0].set_title('Quantidade de clientes por estado civil')

sns.countplot(data=df_train, x='tipo_residencia', palette='mako', ax=ax[3,1])
ax[3,1].set_title('Quantidade de clientes por tipo de residência')
for tick in ax[3,1].get_xticklabels():
    tick.set_rotation(7)

# %%
fig, ax = plt.subplots(nrows=5, ncols=1, figsize=(13,30))

sns.countplot(data=df_train, x='qtd_filhos', palette='mako', ax=ax[0])
ax[0].set_title('Quantidade de clientes por quantidade de filhos')

sns.countplot(data=df_train, x='qt_pessoas_residencia', palette='mako', ax=ax[1])
ax[1].set_title('Quantidade de clientes por quantidade de pessoas na residência')

sns.countplot(data=df_train, x='idade', palette='mako', ax=ax[2])
ax[2].set_title('Quantidade de clientes por idade')

sns.histplot(data=df_train, x='tempo_emprego', palette='dark', bins=50, ax=ax[3])
ax[3].set_title('Quantidade de clientes por tempo de emprego')

sns.histplot(data=df_train, x='renda', palette='dark', bins=50, ax=ax[4])
ax[4].set_title('Quantidade de clientes por renda')
# Out:
# Text(0.5, 1.0, 'Quantidade de clientes por renda')

# %% [markdown]
# ## Descritiva bivariada
#
# Faça uma análise descritiva bivariada de cada variável

# %%
fig, ax = plt.subplots(figsize=(13,7))
sns.lineplot(data=df_train, x='Mes', y='mau', palette='mako', ax=ax, marker='o')
ax.set_title('Proporção de mau para cada mês da base de treino')
ax.set_ylabel("Proporção de inadimplentes")
# Out:
# Text(0, 0.5, 'Proporção de inadimplentes')

# %%
fig, ax = plt.subplots(nrows=4, ncols=2, figsize=(15,26))

sns.lineplot(data=df_train, x='sexo', y='mau', palette='mako', ax=ax[0,0], marker='o')
ax[0,0].set_title('Proporção de mau para sexo feminino e masculino')
ax[0,0].set_ylabel("Proporção de inadimplentes")

sns.lineplot(data=df_train, x='posse_de_veiculo', y='mau', palette='mako', ax=ax[0,1], marker='o')
ax[0,1].set_title('Proporção de mau para clientes que possuem e não possuem veículo')
ax[0,1].set_ylabel("Proporção de inadimplentes")

sns.lineplot(data=df_train, x='posse_de_imovel', y='mau', palette='mako', ax=ax[1,0], marker='o')
ax[1,0].set_title('Proporção de mau para clientes que possuem e não possuem imóvel')
ax[1,0].set_ylabel("Proporção de inadimplentes")

ax[1,1].axis('off')

sns.lineplot(data=df_train, x='tipo_renda', y='mau', palette='mako', ax=ax[2,0], marker='o')
ax[2,0].set_title('Proporção de mau por tipo de renda')
ax[2,0].set_ylabel("Proporção de inadimplentes")

sns.lineplot(data=df_train, x='educacao', y='mau', palette='mako', ax=ax[2,1], marker='o')
ax[2,1].set_title('Proporção de mau por educação')
ax[2,1].set_ylabel("Proporção de inadimplentes")
for tick in ax[2,1].get_xticklabels():
    tick.set_rotation(7)

sns.lineplot(data=df_train, x='estado_civil', y='mau', palette='mako', ax=ax[3,0], marker='o')
ax[3,0].set_title('Proporção de mau por estado civil')
ax[3,0].set_ylabel("Proporção de inadimplentes")

sns.lineplot(data=df_train, x='tipo_residencia', y='mau', palette='mako', ax=ax[3,1], marker='o')
ax[3,1].set_title('Proporção de mau por tipo de residência')
ax[3,1].set_ylabel("Proporção de inadimplentes")
for tick in ax[3,1].get_xticklabels():
    tick.set_rotation(7)

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(13,10))

sns.lineplot(data=df_train, x='qtd_filhos', y='mau', palette='mako', ax=ax[0], marker='o')
ax[0].set_title('Proporção de mau por quantidade de filhos')
ax[0].set_ylabel("Proporção de inadimplentes")

sns.lineplot(data=df_train, x='qt_pessoas_residencia', y='mau', palette='mako', ax=ax[1], marker='o')
ax[1].set_title('Proporção de mau por quantidade de pessoas na residência')
ax[1].set_ylabel("Proporção de inadimplentes")
# Out:
# Text(0, 0.5, 'Proporção de inadimplentes')

# %%
fig, ax = plt.subplots(figsize=(13,7))

cat_1, bins = pd.qcut(df_train['renda'], 15, retbins=True)
df_1 = df_train.groupby(cat_1)
biv = df_1['mau'].mean()

ax = biv.plot.line(marker='o')
ax.set_ylabel("Proporção de inadimplentes")
ticks = plt.xticks(range(len(biv.index.values)), biv.index.values, rotation = 90)
ax.set_title('Proporção de mau para intervalos de renda')
# Out:
# Text(0.5, 1.0, 'Proporção de mau para intervalos de renda')

# %% [markdown]
# ## Desenvolvimento do modelo
#
# Desenvolva um modelo de *credit scoring* através de uma regressão logística.
#
# - Trate valores missings e outliers
# - Trate 'zeros estruturais'
# - Faça agrupamentos de categorias conforme vimos em aula
# - Proponha uma equação preditiva para 'mau'
# - Caso hajam categorias não significantes, justifique

# %%
df_train['mau'] = df_train.mau.astype('int64')
df_train.drop(columns = ['data_ref', 'index', 'Mes'], inplace=True)
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600000 entries, 0 to 599999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   sexo                   600000 non-null  object
#  1   posse_de_veiculo       600000 non-null  object
#  2   posse_de_imovel        600000 non-null  object
#  3   qtd_filhos             600000 non-null  int64
#  4   tipo_renda             600000 non-null  object
#  5   educacao               600000 non-null  object
#  6   estado_civil           600000 non-null  object
#  7   tipo_residencia        600000 non-null  object
#  8   idade                  600000 non-null  int64
#  9   tempo_emprego          499125 non-null  float64
#  10  qt_pessoas_residencia  600000 non-null  float64
#  11  renda                  600000 non-null  float64
#  12  mau                    600000 non-null  int64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 59.5+ MB

# %%
df_train['tempo_emprego'].fillna(value=df_train['tempo_emprego'].mean(), inplace=True)

# %%
metadados = pd.DataFrame(df_train.dtypes, columns=['dtype'])
metadados['nmissing'] = df_train.isna().sum()
metadados['valores_unicos'] = df_train.nunique()
metadados['papel'] = 'covariavel'
metadados.loc['mau','papel'] = 'resposta'
metadados
# Out:
#                          dtype  nmissing  valores_unicos       papel
# sexo                    object         0               2  covariavel
# posse_de_veiculo        object         0               2  covariavel
# posse_de_imovel         object         0               2  covariavel
# qtd_filhos               int64         0               8  covariavel
# tipo_renda              object         0               5  covariavel
# educacao                object         0               5  covariavel
# estado_civil            object         0               5  covariavel
# tipo_residencia         object         0               6  covariavel
# idade                    int64         0              47  covariavel
# tempo_emprego          float64         0            3005  covariavel
# qt_pessoas_residencia  float64         0               9  covariavel
# renda                  float64         0          112472  covariavel
# mau                      int64         0               2    resposta

# %%
for var in metadados[metadados.papel=='covariavel'].index:
    if  (metadados.loc[var, 'valores_unicos']>10):
        metadados.loc[var, 'IV'] = IV(pd.qcut(df_train[var],5,duplicates='drop'), df_train.mau)
    else: 
        metadados.loc[var, 'IV'] = IV(df_train[var], df_train.mau)
    
metadados
# Out:
#                          dtype  nmissing  valores_unicos       papel        IV
# sexo                    object         0               2  covariavel  0.002665
# posse_de_veiculo        object         0               2  covariavel  0.000075
# posse_de_imovel         object         0               2  covariavel  0.009690
# qtd_filhos               int64         0               8  covariavel  0.001689
# tipo_renda              object         0               5  covariavel  0.009718
# educacao                object         0               5  covariavel  0.003690
# estado_civil            object         0               5  covariavel  0.001305
# tipo_residencia         object         0               6  covariavel  0.003330
# idade                    int64         0              47  covariavel  0.018434
# tempo_emprego          float64         0            3005  covariavel  0.283956
# qt_pessoas_residencia  float64         0               9  covariavel       inf
# renda                  float64         0          112472  covariavel  0.959826
# mau                      int64         0               2    resposta       NaN

# %%
biv_discreta('sexo', df_train);

# %%
biv_discreta('posse_de_imovel', df_train);

# %%
biv_discreta('qtd_filhos', df_train);

# %%
biv_discreta('tipo_renda', df_train);

# %%
biv_discreta('educacao', df_train);

# %%
df_train.educacao.replace({'Fundamental':'Fund/Médio/Sup Incomp', 
                      'Médio':'Fund/Médio/Sup Incomp',
                      'Superior incompleto':'Fund/Médio/Sup Incomp',
                      'Superior completo': 'Sup Comp/Pós',
                      'Pós graduação': 'Sup Comp/Pós'
                     }, inplace=True)

biv_discreta('educacao', df_train);
IV(df_train.educacao, df_train.mau)
# Out:
# 0.0034801108923340892

# %%
biv_continua('tempo_emprego', 15, df_train)

# %%
formula = '''
    mau ~ sexo + posse_de_veiculo + posse_de_imovel + qtd_filhos + tipo_renda + 
    educacao + estado_civil + tipo_residencia + idade + tempo_emprego +
    renda
'''

rl = smf.glm(formula, data=df_train, family=sm.families.Binomial()).fit()

rl.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    mau   No. Observations:               600000
# Model:                            GLM   Df Residuals:                   599978
# Model Family:                Binomial   Df Model:                           21
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -1.2488e+05
# Date:                Wed, 05 Oct 2022   Deviance:                   2.4965e+05
# Time:                        10:38:30   Pearson chi2:                 1.57e+16
# No. Iterations:                    11   Pseudo R-squ. (CS):            0.04260
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# Intercept                           -1.4187      0.053    -26.820      0.000      -1.522      -1.315
# sexo[T.M]                           -0.1255      0.013     -9.564      0.000      -0.151      -0.100
# posse_de_veiculo[T.S]                0.0314      0.012      2.535      0.011       0.007       0.056
# posse_de_imovel[T.S]                -0.0848      0.012     -7.183      0.000      -0.108      -0.062
# tipo_renda[T.Bolsista]               0.1216      0.300      0.405      0.685      -0.466       0.710
# tipo_renda[T.Empresário]            -0.0545      0.014     -3.893      0.000      -0.082      -0.027
# tipo_renda[T.Pensionista]           -0.0408      0.020     -2.018      0.044      -0.080      -0.001
# tipo_renda[T.Servidor público]      -0.0329      0.023     -1.415      0.157      -0.078       0.013
# educacao[T.Sup Comp/Pós]            -0.0568      0.013     -4.337      0.000      -0.082      -0.031
# estado_civil[T.Separado]             0.0375      0.024      1.578      0.115      -0.009       0.084
# estado_civil[T.Solteiro]             0.0055      0.017      0.315      0.753      -0.029       0.039
# estado_civil[T.União]                0.0473      0.020      2.324      0.020       0.007       0.087
# estado_civil[T.Viúvo]               -0.0345      0.029     -1.189      0.234      -0.091       0.022
# tipo_residencia[T.Casa]             -0.0879      0.044     -1.995      0.046      -0.174      -0.002
# tipo_residencia[T.Com os pais]      -0.0731      0.050     -1.475      0.140      -0.170       0.024
# tipo_residencia[T.Comunitário]      -0.1402      0.089     -1.571      0.116      -0.315       0.035
# tipo_residencia[T.Estúdio]          -0.0327      0.082     -0.397      0.692      -0.194       0.129
# tipo_residencia[T.Governamental]    -0.0834      0.053     -1.565      0.118      -0.188       0.021
# qtd_filhos                           0.0036      0.008      0.452      0.651      -0.012       0.019
# idade                                0.0003      0.001      0.387      0.699      -0.001       0.002
# tempo_emprego                       -0.0236      0.002    -13.106      0.000      -0.027      -0.020
# renda                               -0.0001   1.09e-06    -93.689      0.000      -0.000   -9.96e-05
# ====================================================================================================
# """

# %%
formula = '''
    mau ~ sexo + posse_de_imovel + educacao +
    tempo_emprego + renda
'''

rl = smf.glm(formula, data=df_train, family=sm.families.Binomial()).fit()

rl.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    mau   No. Observations:               600000
# Model:                            GLM   Df Residuals:                   599994
# Model Family:                Binomial   Df Model:                            5
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:            -1.2490e+05
# Date:                Wed, 05 Oct 2022   Deviance:                   2.4969e+05
# Time:                        10:38:39   Pearson chi2:                 1.59e+16
# No. Iterations:                    11   Pseudo R-squ. (CS):            0.04253
# Covariance Type:            nonrobust
# ============================================================================================
#                                coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# Intercept                   -1.4931      0.014   -107.439      0.000      -1.520      -1.466
# sexo[T.M]                   -0.1072      0.012     -8.926      0.000      -0.131      -0.084
# posse_de_imovel[T.S]        -0.0897      0.011     -7.845      0.000      -0.112      -0.067
# educacao[T.Sup Comp/Pós]    -0.0569      0.013     -4.477      0.000      -0.082      -0.032
# tempo_emprego               -0.0245      0.002    -14.616      0.000      -0.028      -0.021
# renda                       -0.0001   1.08e-06    -94.209      0.000      -0.000   -9.96e-05
# ============================================================================================
# """

# %% [markdown]
# ## Avaliação do modelo
#
# Avalie o poder discriminante do modelo pelo menos avaliando acurácia, KS e Gini.
#
# Avalie estas métricas nas bases de desenvolvimento e *out of time*.

# %%
df_train['score'] = rl.predict(df_train)

acc = metrics.accuracy_score(df_train.mau, df_train.score>.068)
fpr, tpr, thresholds = metrics.roc_curve(df_train.mau, df_train.score)
auc = metrics.auc(fpr, tpr)
gini = 2*auc -1
ks = ks_2samp(df_train.loc[df_train.mau == 1, 'score'], df_train.loc[df_train.mau != 1, 'score']).statistic

print('Acurácia: {0:.1%} \nAUC: {1:.1%} \nGINI: {2:.1%}\nKS: {3:.1%}'
      .format(acc, auc, gini, ks))
# Out:
# Acurácia: 59.4%
# AUC: 76.6%
# GINI: 53.2%
# KS: 39.4%

# %%
fpr, tpr, thresholds = metrics.roc_curve(df_train['mau'], df_train['score'])

plt.figure()
lw = 2

fpr, tpr, thresholds = metrics.roc_curve(df_train['mau'], df_train['score'])
auc_ = metrics.auc(fpr, tpr)
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % auc_)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC curve')
plt.legend(loc="lower right")
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

score_pop1 = df_train.loc[df_train['mau']==1,'score']
ax.plot(np.sort(score_pop1), np.linspace(0, 1, len(score_pop1), endpoint=False), label='Mau')

score_pop2 = df_train.loc[df_train['mau']!=1,'score']
ax.plot(np.sort(score_pop2), np.linspace(0, 1, len(score_pop2), endpoint=False), label='Bom')
ax.legend()

ax.set_xlabel('P')
ax.set_ylabel('Função Distribuição Acumulada')
# Out:
# Text(0, 0.5, 'Função Distribuição Acumulada')

# %% [markdown]
# # a - Criar um pipeline utilizando o sklearn pipeline para o preprocessamento
# ## Pré processamento
# ### Substituição de nulos (nans)
#
# Existe nulos na base? é dado numérico ou categórico? qual o valor de substituição? média? valor mais frequente? etc

# %%
df.isna().sum()
# Out:
# index                         0
# sexo                          0
# posse_de_veiculo              0
# posse_de_imovel               0
# qtd_filhos                    0
# tipo_renda                    0
# educacao                      0
# estado_civil                  0
# tipo_residencia               0
# idade                         0
# tempo_emprego            125957
# qt_pessoas_residencia         0
# renda                         0
# mau                           0
# dtype: int64

# %%
df['tempo_emprego'] = df['tempo_emprego'].fillna(df['tempo_emprego'].median())

# %% [markdown]
# ### Remoção de outliers
#
# Como identificar outlier? Substituir o outlier por algum valor? Remover a linha?

# %%
sns.regplot(y='renda', x='tempo_emprego', data=df)
# Out:
# <AxesSubplot:xlabel='tempo_emprego', ylabel='renda'>

# %% [markdown]
# ### Seleção de variáveis
#
# Qual tipo de técnica? Boruta? Feature importance?

# %%
variaveis = ['renda', 'posse_de_imovel', 'idade', 'tempo_emprego',
       'qt_pessoas_residencia']

# %%
dataset = df.sample(400)

# %%
exp_aula4 = setup(data = dataset, target = 'mau', experiment_name='credit_1',
                  normalize=True, normalize_method='zscore', 
                  transformation=True, transformation_method = 'quantile',
                  fix_imbalance=True)
# Out:
# <style type="text/css">
# #T_e7167_row10_col1, #T_e7167_row17_col1, #T_e7167_row19_col1, #T_e7167_row21_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e7167">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7167_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e7167_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7167_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e7167_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e7167_row0_col1" class="data row0 col1" >2564</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e7167_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e7167_row1_col1" class="data row1 col1" >mau</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e7167_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e7167_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e7167_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_e7167_row3_col1" class="data row3 col1" >(11084, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e7167_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_e7167_row4_col1" class="data row4 col1" >(17518, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e7167_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_e7167_row5_col1" class="data row5 col1" >(14192, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e7167_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_e7167_row6_col1" class="data row6 col1" >(3326, 24)</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e7167_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_e7167_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e7167_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_e7167_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e7167_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_e7167_row9_col1" class="data row9 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e7167_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_e7167_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e7167_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_e7167_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e7167_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_e7167_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e7167_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_e7167_row13_col1" class="data row13 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e7167_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_e7167_row14_col1" class="data row14 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e7167_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_e7167_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e7167_row16_col0" class="data row16 col0" >Low variance threshold</td>
#       <td id="T_e7167_row16_col1" class="data row16 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e7167_row17_col0" class="data row17 col0" >Fix imbalance</td>
#       <td id="T_e7167_row17_col1" class="data row17 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e7167_row18_col0" class="data row18 col0" >Fix imbalance method</td>
#       <td id="T_e7167_row18_col1" class="data row18 col1" >SMOTE</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e7167_row19_col0" class="data row19 col0" >Transformation</td>
#       <td id="T_e7167_row19_col1" class="data row19 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e7167_row20_col0" class="data row20 col0" >Transformation method</td>
#       <td id="T_e7167_row20_col1" class="data row20 col1" >quantile</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e7167_row21_col0" class="data row21 col0" >Normalize</td>
#       <td id="T_e7167_row21_col1" class="data row21 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_e7167_row22_col0" class="data row22 col0" >Normalize method</td>
#       <td id="T_e7167_row22_col1" class="data row22 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_e7167_row23_col0" class="data row23 col0" >Fold Generator</td>
#       <td id="T_e7167_row23_col1" class="data row23 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_e7167_row24_col0" class="data row24 col0" >Fold Number</td>
#       <td id="T_e7167_row24_col1" class="data row24 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_e7167_row25_col0" class="data row25 col0" >CPU Jobs</td>
#       <td id="T_e7167_row25_col1" class="data row25 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_e7167_row26_col0" class="data row26 col0" >Use GPU</td>
#       <td id="T_e7167_row26_col1" class="data row26 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_e7167_row27_col0" class="data row27 col0" >Log Experiment</td>
#       <td id="T_e7167_row27_col1" class="data row27 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_e7167_row28_col0" class="data row28 col0" >Experiment Name</td>
#       <td id="T_e7167_row28_col1" class="data row28 col1" >credit_1</td>
#     </tr>
#     <tr>
#       <th id="T_e7167_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_e7167_row29_col0" class="data row29 col0" >USI</td>
#       <td id="T_e7167_row29_col1" class="data row29 col1" >2d13</td>
#     </tr>
#   </tbody>
# </table>

# %%
best_model = compare_models(fold=4, sort='AUC')
# Out:
# <style type="text/css">
# #T_d36e8 th {
#   text-align: left;
# }
# #T_d36e8_row0_col0, #T_d36e8_row0_col1, #T_d36e8_row0_col3, #T_d36e8_row0_col4, #T_d36e8_row1_col0, #T_d36e8_row1_col1, #T_d36e8_row1_col2, #T_d36e8_row1_col3, #T_d36e8_row1_col5, #T_d36e8_row1_col6, #T_d36e8_row1_col7, #T_d36e8_row2_col0, #T_d36e8_row2_col1, #T_d36e8_row2_col2, #T_d36e8_row2_col3, #T_d36e8_row2_col4, #T_d36e8_row2_col5, #T_d36e8_row2_col6, #T_d36e8_row2_col7, #T_d36e8_row3_col0, #T_d36e8_row3_col1, #T_d36e8_row3_col2, #T_d36e8_row3_col3, #T_d36e8_row3_col4, #T_d36e8_row3_col5, #T_d36e8_row3_col6, #T_d36e8_row3_col7, #T_d36e8_row4_col0, #T_d36e8_row4_col2, #T_d36e8_row4_col3, #T_d36e8_row4_col4, #T_d36e8_row4_col5, #T_d36e8_row4_col6, #T_d36e8_row4_col7, #T_d36e8_row5_col0, #T_d36e8_row5_col1, #T_d36e8_row5_col2, #T_d36e8_row5_col3, #T_d36e8_row5_col4, #T_d36e8_row5_col5, #T_d36e8_row5_col6, #T_d36e8_row5_col7, #T_d36e8_row6_col0, #T_d36e8_row6_col1, #T_d36e8_row6_col2, #T_d36e8_row6_col3, #T_d36e8_row6_col4, #T_d36e8_row6_col5, #T_d36e8_row6_col6, #T_d36e8_row6_col7, #T_d36e8_row7_col0, #T_d36e8_row7_col1, #T_d36e8_row7_col2, #T_d36e8_row7_col4, #T_d36e8_row7_col5, #T_d36e8_row7_col6, #T_d36e8_row7_col7, #T_d36e8_row8_col0, #T_d36e8_row8_col2, #T_d36e8_row8_col3, #T_d36e8_row8_col4, #T_d36e8_row8_col5, #T_d36e8_row8_col6, #T_d36e8_row8_col7, #T_d36e8_row9_col0, #T_d36e8_row9_col1, #T_d36e8_row9_col2, #T_d36e8_row9_col4, #T_d36e8_row9_col5, #T_d36e8_row9_col6, #T_d36e8_row9_col7, #T_d36e8_row10_col0, #T_d36e8_row10_col1, #T_d36e8_row10_col2, #T_d36e8_row10_col3, #T_d36e8_row10_col4, #T_d36e8_row10_col5, #T_d36e8_row10_col6, #T_d36e8_row10_col7, #T_d36e8_row11_col0, #T_d36e8_row11_col1, #T_d36e8_row11_col2, #T_d36e8_row11_col3, #T_d36e8_row11_col4, #T_d36e8_row11_col5, #T_d36e8_row11_col6, #T_d36e8_row11_col7, #T_d36e8_row12_col0, #T_d36e8_row12_col1, #T_d36e8_row12_col2, #T_d36e8_row12_col3, #T_d36e8_row12_col4, #T_d36e8_row12_col5, #T_d36e8_row12_col6, #T_d36e8_row12_col7, #T_d36e8_row13_col0, #T_d36e8_row13_col1, #T_d36e8_row13_col2, #T_d36e8_row13_col3, #T_d36e8_row13_col4, #T_d36e8_row13_col5, #T_d36e8_row13_col6, #T_d36e8_row13_col7 {
#   text-align: left;
# }
# #T_d36e8_row0_col2, #T_d36e8_row0_col5, #T_d36e8_row0_col6, #T_d36e8_row0_col7, #T_d36e8_row1_col4, #T_d36e8_row4_col1, #T_d36e8_row7_col3, #T_d36e8_row8_col1, #T_d36e8_row9_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_d36e8_row0_col8, #T_d36e8_row1_col8, #T_d36e8_row2_col8, #T_d36e8_row3_col8, #T_d36e8_row4_col8, #T_d36e8_row5_col8, #T_d36e8_row6_col8, #T_d36e8_row7_col8, #T_d36e8_row8_col8, #T_d36e8_row9_col8, #T_d36e8_row10_col8, #T_d36e8_row11_col8, #T_d36e8_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_d36e8_row12_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_d36e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d36e8_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_d36e8_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_d36e8_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_d36e8_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_d36e8_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_d36e8_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_d36e8_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_d36e8_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_d36e8_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d36e8_level0_row0" class="row_heading level0 row0" >knn</th>
#       <td id="T_d36e8_row0_col0" class="data row0 col0" >K Neighbors Classifier</td>
#       <td id="T_d36e8_row0_col1" class="data row0 col1" >0.6731</td>
#       <td id="T_d36e8_row0_col2" class="data row0 col2" >0.5607</td>
#       <td id="T_d36e8_row0_col3" class="data row0 col3" >0.4291</td>
#       <td id="T_d36e8_row0_col4" class="data row0 col4" >0.1162</td>
#       <td id="T_d36e8_row0_col5" class="data row0 col5" >0.1828</td>
#       <td id="T_d36e8_row0_col6" class="data row0 col6" >0.0561</td>
#       <td id="T_d36e8_row0_col7" class="data row0 col7" >0.0751</td>
#       <td id="T_d36e8_row0_col8" class="data row0 col8" >1.0725</td>
#     </tr>
#     <tr>
#       <th id="T_d36e8_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_d36e8_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_d36e8_row1_col1" class="data row1 col1" >0.7428</td>
#       <td id="T_d36e8_row1_col2" class="data row1 col2" >0.5562</td>
#       <td id="T_d36e8_row1_col3" class="data row1 col3" >0.3112</td>
#       <td id="T_d36e8_row1_col4" class="data row1 col4" >0.1192</td>
#       <td id="T_d36e8_row1_col5" class="data row1 col5" >0.1722</td>
#       <td id="T_d36e8_row1_col6" class="data row1 col6" >0.0554</td>
#       <td id="T_d36e8_row1_col7" class="data row1 col7" >0.0639</td>
#       <td id="T_d36e8_row1_col8" class="data row1 col8" >5.1175</td>
#     </tr>
#     <tr>
#       <th id="T_d36e8_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_d36e8_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_d36e8_row2_col1" class="data row2 col1" >0.7752</td>
#       <td id="T_d36e8_row2_col2" class="data row2 col2" >0.5558</td>
#       <td id="T_d36e8_row2_col3" class="data row2 col3" >0.2311</td>
#       <td id="T_d36e8_row2_col4" class="data row2 col4" >0.1113</td>
#       <td id="T_d36e8_row2_col5" class="data row2 col5" >0.1498</td>
#       <td id="T_d36e8_row2_col6" class="data row2 col6" >0.0390</td>
#       <td id="T_d36e8_row2_col7" class="data row2 col7" >0.0422</td>
#       <td id="T_d36e8_row2_col8" class="data row2 col8" >0.1925</td>
#     </tr>
#     <tr>
#       <th id="T_d36e8_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_d36e8_row3_col0" class="data row3 col0" >Random Forest Classifier</td>
#       <td id="T_d36e8_row3_col1" class="data row3 col1" >0.1329</td>
#       <td id="T_d36e8_row3_col2" class="data row3 col2" >0.5482</td>
#       <td id="T_d36e8_row3_col3" class="data row3 col3" >0.9562</td>
#       <td id="T_d36e8_row3_col4" class="data row3 col4" >0.0864</td>
#       <td id="T_d36e8_row3_col5" class="data row3 col5" >0.1584</td>
#       <td id="T_d36e8_row3_col6" class="data row3 col6" >0.0022</td>
#       <td id="T_d36e8_row3_col7" class="data row3 col7" >0.0144</td>
#       <td id="T_d36e8_row3_col8" class="data row3 col8" >0.3800</td>
#     </tr>
#     <tr>
#       <th id="T_d36e8_level0_row4" class="row_heading level0 row4" >qda</th>
#       <td id="T_d36e8_row4_col0" class="data row4 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_d36e8_row4_col1" class="data row4 col1" >0.9147</td>
#       <td id="T_d36e8_row4_col2" class="data row4 col2" >0.5282</td>
#       <td id="T_d36e8_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_d36e8_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_d36e8_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_d36e8_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_d36e8_row4_col7" class="data row4 col7" >0.0000</td>
#       <td id="T_d36e8_row4_col8" class="data row4 col8" >0.2325</td>
#     </tr>
#     <tr>
#       <th id="T_d36e8_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_d36e8_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_d36e8_row5_col1" class="data row5 col1" >0.5407</td>
#       <td id="T_d36e8_row5_col2" class="data row5 col2" >0.5269</td>
#       <td id="T_d36e8_row5_col3" class="data row5 col3" >0.4820</td>
#       <td id="T_d36e8_row5_col4" class="data row5 col4" >0.0901</td>
#       <td id="T_d36e8_row5_col5" class="data row5 col5" >0.1518</td>
#       <td id="T_d36e8_row5_col6" class="data row5 col6" >0.0094</td>
#       <td id="T_d36e8_row5_col7" class="data row5 col7" >0.0158</td>
#       <td
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]

# %%
plot_model(best_model, plot='feature')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 plot_model(best_model, plot='feature')
#
# File ~\anaconda3\Nova pasta\lib\site-packages\pycaret\utils\generic.py:950, in check_if_global_is_not_none.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     948     if globals_d[name] is None:
#     949         raise ValueError(message)
# --> 950 return func(*args, **kwargs)
#
# File ~\anaconda3\Nova pasta\lib\site-packages\pycaret\classification\functional.py:1739, in plot_model(estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, use_train_data, verbose, display_format)
#    1618 @check_if_global_is_not_none(globals(), _CURRENT_EXPERIMENT_DECORATOR_DICT)
#    1619 def plot_model(
#    1620     estimator,
#    (...)
#    1630     display_format: Optional[str] = None,
#    1631 ) -> Optional[str]:
#    1633     """
#    1634     This function analyzes the performance of a trained model on holdout set.
#    1635     It may require re-training the model in certain cases.
#    (...)
#    1736
#    1737     """
# -> 1739     return _CURRENT_EXPERIMENT.plot_model(
#    1740         estimator=estimator,
#    1741         plot=plot,
#    1742         scale=scale,
#    1743         save=save,
#    1744         fold=fold,
#    1745         fit_kwargs=fit_kwargs,
#    1746         plot_kwargs=plot_kwargs,
#    1747         groups=groups,
#    1748         verbose=verbose,
#    1749         use_train_data=use_train_data,
#    1750         display_format=display_format,
#    1751     )
#
# File ~\anaconda3\Nova pasta\lib\site-packages\pycaret\classification\oop.py:2079, in ClassificationExperiment.plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, use_train_data, verbose, display_format)
#    1958 def plot_model(
#    1959     self,
#    1960     estimator,
#    (...)
#    1970     display_format: Optional[str] = None,
#    1971 ) -> Optional[str]:
#    1973     """
#    1974     This function analyzes the performance of a trained model on holdout set.
#    1975     It may require re-training the model in certain cases.
#    (...)
#    2076
#    2077     """
# -> 2079     return super().plot_model(
#    2080         estimator=estimator,
#    2081         plot=plot,
#    2082         scale=scale,
#    2083         save=save,
#    2084         fold=fold,
#    2085         fit_kwargs=fit_kwargs,
#    2086         plot_kwargs=plot_kwargs,
#    2087         groups=groups,
#    2088         verbose=verbose,
#    2089         use_train_data=use_train_data,
#    2090         display_format=display_format,
#    2091     )
#
# File ~\anaconda3\Nova pasta\lib\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py:2094, in _TabularExperiment.plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, use_train_data, verbose, display_format)
#    1980 def plot_model(
#    1981     self,
#    1982     estimator,
#    (...)
#    1994     display_format: Optional[str] = None,
#    1995 ) -> Optional[str]:
#    1997     """
#    1998     This function takes a trained model object and returns a plot based on the
#    1999     test / hold-out set. The process may require the model to be re-trained in
#    (...)
#    2092
#    2093     """
# -> 2094     return self._plot_model(
#    2095         estimator=estimator,
#    2096         plot=plot,
#    2097         scale=scale,
#    2098         save=save,
#    2099         fold=fold,
#    2100         fit_kwargs=fit_kwargs,
#    2101         plot_kwargs=plot_kwargs,
#    2102         groups=groups,
#    2103         feature_name=feature_name,
#    2104         label=label,
#    2105         use_train_data=use_train_data,
#    2106         verbose=verbose,
#    2107         display_format=display_format,
#    2108     )
#
# File ~\anaconda3\Nova pasta\lib\site-packages\pycaret\internal\pycaret_experiment\tabular_experiment.py:474, in _TabularExperiment._plot_model(self, estimator, plot, scale, save, fold, fit_kwargs, plot_kwargs, groups, feature_name, label, use_train_data, verbose, system, display, display_format)
#     470 # checking for feature plot
#     471 if not (
#     472     hasattr(estimator, "coef_") or hasattr(estimator, "feature_importances_")
#     473 ) and (plot == "feature" or plot == "feature_all" or plot == "rfe"):
# --> 474     raise TypeError(
#     475         "Feature Importance and RFE plots not available for estimators that doesnt support coef_ or feature_importances_ attribute."
#     476     )
#     478 # checking fold parameter
#     479 if fold is not None and not (
#     480     type(fold) is int or is_sklearn_cv_generator(fold)
#     481 ):
#
# TypeError: Feature Importance and RFE plots not available for estimators that doesnt support coef_ or feature_importances_ attribute.

# %%
save_model(best_model,'LR Model Aula 5 062022')

# %% [markdown]
# ### Redução de dimensionalidade (PCA)
#
# Aplicar PCA para reduzir a dimensionalidade para 5

# %%
X_digits, y_digits = load_digits(return_X_y=True, as_frame=True)
X_train, X_test, y_train, y_test = train_test_split(X_digits, y_digits, test_size=0.3, random_state=10)

# %%
pca_pipe = PCA(n_components=5)

# %%
pca.fit(X_train)
X_train = pca.transform(X_train)

# %%
X_test = pca.transform(X_test)

# %%
pipe = Pipeline(steps=[("pca", pca_pipe)])

# %% [markdown]
# ### Criação de dummies
#
# Aplicar o get_dummies() ou onehotencoder() para transformar colunas catégoricas do dataframe em colunas de 0 e 1.
# - sexo
# - posse_de_veiculo
# - posse_de_imovel
# - tipo_renda
# - educacao
# - estado_civil
# - tipo_residencia

# %%
df1 = pd.get_dummies(dataset, columns=['tipo_residencia'
                                                 ,'estado_civil'
                                                 ,'educacao'
                                                 ,'tipo_renda'
                                                 ,'posse_de_imovel'
                                                 ,'posse_de_veiculo'
                                                 ,'sexo']
                               , drop_first=True)
df1.head(20)
# Out:
#             index  qtd_filhos  idade  tempo_emprego  qt_pessoas_residencia  \
# data_ref
# 2015-04-01  16353           0     43      15.972603                    2.0
# 2015-09-01  15757           0     29       1.931507                    2.0
# 2015-04-01   6621           1     29       7.101370                    3.0
# 2015-03-01   7246           1     31       2.043836                    2.0
# 2015-03-01  10302           2     42      15.057534                    4.0
# 2015-08-01  15595           1     32       3.287671                    3.0
# 2015-01-01  14674           0     36       8.638356                    1.0
# 2015-10-01   3288           1     40       8.906849                    3.0
# 2016-01-01   6457           1     34       2.243836                    3.0
# 2015-06-01   7837           1     36       7.473973                    3.0
# 2015-10-01   5412           0     58      12.767123                    2.0
# 2015-09-01    367           0     28       1.523288                    1.0
# 2015-10-01   3102           0     54      15.558904                    2.0
# 2015-02-01  13401           1     29       0.347945                    3.0
# 2015-05-01   3406           0     30       0.882192                    1.0
# 2015-02-01   2972           0     56       6.046575                    2.0
# 2015-07-01  13716           1     44      10.120548                    3.0
# 2015-05-01   3153           2     42       7.887671                    4.0
# 2015-06-01   7635           0     67       6.046575                    1.0
# 2016-03-01   3258           1     43       6.136986                    3.0
#
#                renda    mau  tipo_residencia_Casa  \
# data_ref
# 2015-04-01  41115.74  False                     1
# 2015-09-01  58761.48  False                     1
# 2015-04-01  19281.89  False                     0
# 2015-03-01   6956.21  False                     1
# 2015-03-01  40594.24  False                     1
# 2015-08-01  17522.39  False                     1
# 2015-01-01   1488.46  False                     1
# 2015-10-01  31838.67  False                     1
# 2016-01-01   9408.23  False                     1
# 2015-06-01  37353.24  False                     1
# 2015-10-01   6345.88  False                     1
# 2015-09-01   7027.60  False                     0
# 2015-10-01  58119.62  False                     1
# 2015-02-01   2705.90  False                     1
# 2015-05-01   1656.09   True                     1
# 2015-02-01   2942.88  False                     1
# 2015-07-01  27919.31  False                     1
# 2015-05-01  97637.16  False                     1
# 2015-06-01  53250.22  False                     1
# 2016-03-01   2226.21  False                     1
#
#             tipo_residencia_Com os pais  tipo_residencia_Comunitário  ...  \
# data_ref                                                              ...
# 2015-04-01                            0                            0  ...
# 2015-09-01                            0                            0  ...
# 2015-04-01                            1                            0  ...
# 2015-03-01                            0                            0  ...
# 2015-03-01                            0                            0  ...
# 2015-08-01                            0                            0  ...
# 2015-01-01                            0                            0  ...
# 2015-10-01                            0                            0  ...
# 2016-01-01                            0                            0  ...
# 2015-06-01                            0                            0  ...
# 2015-10-01                            0                            0  ...
# 2015-09-01                            1                            0  ...
# 2015-10-01                            0                            0  ...
# 2015-02-01                            0                            0  ...
# 2015-05-01                            0                            0  ...
# 2015-02-01                            0                            0  ...
# 2015-07-01                            0                            0  ...
# 2015-05-01                            0                            0  ...
# 2015-06-01                            0                            0  ...
# 2016-03-01                            0                            0  ...
#
#             estado_civil_Viúvo  educacao_Médio  educacao_Superior completo  \
# data_ref
# 2015-04-01                   0               1                           0
# 2015-09-01                   0               0                           1
# 2015-04-01                   0               1                           0
# 2015-03-01                   0               1                           0
# 2015-03-01                   0               1                           0
# 2015-08-01                   0               1                           0
# 2015-01-01                   0               1                           0
# 2015-10-01                   0               1                           0
# 2016-01-01                   0               1                           0
# 2015-06-01                   0               1                           0
# 2015-10-01                   0               1                           0
# 2015-09-01                   0               1                           0
# 2015-10-01                   0               0                           1
# 2015-02-01                   0               1                           0
# 2015-05-01                   0               1                           0
# 2015-02-01                   0               1                           0
# 2015-07-01                   0               1                           0
# 2015-05-01                   0               1                           0
# 2015-06-01                   1               1                           0
# 2016-03-01                   0               1                           0
#
#             educacao_Superior incompleto  tipo_renda_Empresário  \
# data_ref
# 2015-04-01                             0                      1
# 2015-09-01                             0                      0
# 2015-04-01                             0                      0
# 2015-03-01                             0                      0
# 2015-03-01                             0                      0
# 2015-08-01                             0                      1
# 2015-01-01                             0                      1
# 2015-10-01                             0                      1
# 2016-01-01                             0                      0
# 2015-06-01                             0                      0
# 2015-10-01                             0                      0
# 2015-09-01                             0                      1
# 2015-10-01                             0                      1
# 2015-02-01                             0                      0
# 2015-05-01                             0                      0
# 2015-02-01                             0                      0
# 2015-07-01                             0                      0
# 2015-05-01                             0                      1
# 2015-06-01                             0                      0
# 2016-03-01                             0                      0
#
#             tipo_renda_Pensionista  tipo_renda_Servidor público  \
# data_ref
# 2015-04-01                       0                            0
# 2015-09-01                       0                            0
# 2015-04-01                       0                            0
# 2015-03-01                       0                            0
# 2015-03-01                       0                            0
# 2015-08-01                       0                            0
# 2015-01-01                       0                            0
# 2015-10-01                       0                            0
# 2016-01-01                       0                            0
# 2015-06-01                       0                            0
# 2015-10-01                       0                            0
# 2015-09-01                       0                            0
# 2015-10-01                       0                            0
# 2015-02-01                       0                            0
# 2015-05-01                       0                            0
# 2015-02-01                       1                            0
# 2015-07-01                       0                            0
# 2015-05-01                       0                            0
# 2015-06-01                       1                            0
# 2016-03-01                       0                            0
#
#             posse_de_imovel_S  posse_de_veiculo_S  sexo_M
# data_ref
# 2015-04-01                  1                   0       0
# 2015-09-01                  1                   1       1
# 2015-04-01                  0                   0       0
# 2015-03-01                  1                   1       1
# 2015-03-01                  1                   0       0
# 2015-08-01                  1                   0       1
# 2015-01-01                  1                   0       0
# 2015-10-01                  1                   0       0
# 2016-01-01                  1                   1       0
# 2015-06-01                  1                   0       1
# 2015-10-01                  1                   0       0
# 2015-09-01                  0                   1       1
# 2015-10-01                  1                   1       0
# 2015-02-01                  1                   0       0
# 2015-05-01                  1                   0       0
# 2015-02-01                  0                   0       0
# 2015-07-01                  1                   0       0
# 2015-05-01                  0                   1       1
# 2015-06-01                  1                   0       0
# 2016-03-01                  1                   1       1
#
# [20 rows x 25 columns]

# %% [markdown]
# ### Pipeline
#
# Crie um pipeline contendo essas funções.
#
# preprocessamento()
# - substituicao de nulos
# - remoção outliers
# - PCA
# - Criação de dummy de pelo menos 1 variável (posse_de_veiculo)

# %%
exp_aula4 = setup(data = dataset, remove_outliers=True, pca_method=True, fix_imbalance_method=True, target = 'posse_de_veiculo' )

# %% [markdown]
# # b - Pycaret na base de dados
#
# Utilize o pycaret para pre processar os dados e rodar o modelo **lightgbm**. Faça todos os passos a passos da aula e gere os gráficos finais. E o pipeline de toda a transformação.

# %%
data = dataset.sample(frac=0.95, random_state=786)
data_unseen = dataset.drop(data.index)
data.reset_index(inplace=True, drop=True)
data_unseen.reset_index(inplace=True, drop=True)
print('Conjunto de dados para modelagem (treino e teste): ' + str(data.shape))
print('Conjunto de dados não usados no treino/teste, apenas como validação: ' + str(data_unseen.shape))
# Out:
# Conjunto de dados para modelagem (treino e teste): (380, 14)
# Conjunto de dados não usados no treino/teste, apenas como validação: (0, 14)

# %%
from pycaret.classification import *

# %%
best_model = compare_models(fold=5)
# Out:
# <style type="text/css">
# #T_67276 th {
#   text-align: left;
# }
# #T_67276_row0_col0, #T_67276_row0_col2, #T_67276_row0_col3, #T_67276_row0_col4, #T_67276_row0_col5, #T_67276_row0_col6, #T_67276_row0_col7, #T_67276_row1_col0, #T_67276_row1_col2, #T_67276_row1_col3, #T_67276_row1_col4, #T_67276_row1_col5, #T_67276_row1_col6, #T_67276_row1_col7, #T_67276_row2_col0, #T_67276_row2_col1, #T_67276_row2_col2, #T_67276_row2_col3, #T_67276_row2_col4, #T_67276_row2_col5, #T_67276_row2_col6, #T_67276_row2_col7, #T_67276_row3_col0, #T_67276_row3_col1, #T_67276_row3_col2, #T_67276_row3_col3, #T_67276_row3_col4, #T_67276_row3_col5, #T_67276_row3_col6, #T_67276_row3_col7, #T_67276_row4_col0, #T_67276_row4_col1, #T_67276_row4_col2, #T_67276_row4_col3, #T_67276_row4_col5, #T_67276_row5_col0, #T_67276_row5_col1, #T_67276_row5_col3, #T_67276_row5_col4, #T_67276_row5_col6, #T_67276_row5_col7, #T_67276_row6_col0, #T_67276_row6_col1, #T_67276_row6_col2, #T_67276_row6_col3, #T_67276_row6_col4, #T_67276_row6_col5, #T_67276_row6_col6, #T_67276_row6_col7, #T_67276_row7_col0, #T_67276_row7_col1, #T_67276_row7_col2, #T_67276_row7_col3, #T_67276_row7_col4, #T_67276_row7_col5, #T_67276_row7_col6, #T_67276_row7_col7, #T_67276_row8_col0, #T_67276_row8_col1, #T_67276_row8_col2, #T_67276_row8_col3, #T_67276_row8_col4, #T_67276_row8_col5, #T_67276_row8_col6, #T_67276_row8_col7, #T_67276_row9_col0, #T_67276_row9_col1, #T_67276_row9_col2, #T_67276_row9_col3, #T_67276_row9_col4, #T_67276_row9_col5, #T_67276_row9_col6, #T_67276_row9_col7, #T_67276_row10_col0, #T_67276_row10_col1, #T_67276_row10_col2, #T_67276_row10_col3, #T_67276_row10_col4, #T_67276_row10_col5, #T_67276_row10_col6, #T_67276_row10_col7, #T_67276_row11_col0, #T_67276_row11_col1, #T_67276_row11_col2, #T_67276_row11_col3, #T_67276_row11_col4, #T_67276_row11_col5, #T_67276_row11_col6, #T_67276_row11_col7, #T_67276_row12_col0, #T_67276_row12_col1, #T_67276_row12_col2, #T_67276_row12_col3, #T_67276_row12_col4, #T_67276_row12_col5, #T_67276_row12_col6, #T_67276_row12_col7, #T_67276_row13_col0, #T_67276_row13_col1, #T_67276_row13_col2, #T_67276_row13_col4, #T_67276_row13_col5, #T_67276_row13_col6, #T_67276_row13_col7 {
#   text-align: left;
# }
# #T_67276_row0_col1, #T_67276_row1_col1, #T_67276_row4_col4, #T_67276_row4_col6, #T_67276_row4_col7, #T_67276_row5_col2, #T_67276_row5_col5, #T_67276_row13_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_67276_row0_col8, #T_67276_row1_col8, #T_67276_row2_col8, #T_67276_row4_col8, #T_67276_row5_col8, #T_67276_row6_col8, #T_67276_row7_col8, #T_67276_row8_col8, #T_67276_row9_col8, #T_67276_row10_col8, #T_67276_row11_col8, #T_67276_row12_col8, #T_67276_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_67276_row3_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_67276">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67276_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_67276_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_67276_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_67276_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_67276_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_67276_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_67276_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_67276_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_67276_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67276_level0_row0" class="row_heading level0 row0" >qda</th>
#       <td id="T_67276_row0_col0" class="data row0 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_67276_row0_col1" class="data row0 col1" >0.9147</td>
#       <td id="T_67276_row0_col2" class="data row0 col2" >0.5273</td>
#       <td id="T_67276_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_67276_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_67276_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_67276_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_67276_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_67276_row0_col8" class="data row0 col8" >0.1460</td>
#     </tr>
#     <tr>
#       <th id="T_67276_level0_row1" class="row_heading level0 row1" >dummy</th>
#       <td id="T_67276_row1_col0" class="data row1 col0" >Dummy Classifier</td>
#       <td id="T_67276_row1_col1" class="data row1 col1" >0.9147</td>
#       <td id="T_67276_row1_col2" class="data row1 col2" >0.5000</td>
#       <td id="T_67276_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_67276_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_67276_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_67276_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_67276_row1_col7" class="data row1 col7" >0.0000</td>
#       <td id="T_67276_row1_col8" class="data row1 col8" >0.1420</td>
#     </tr>
#     <tr>
#       <th id="T_67276_level0_row2" class="row_heading level0 row2" >lda</th>
#       <td id="T_67276_row2_col0" class="data row2 col0" >Linear Discriminant Analysis</td>
#       <td id="T_67276_row2_col1" class="data row2 col1" >0.7862</td>
#       <td id="T_67276_row2_col2" class="data row2 col2" >0.5635</td>
#       <td id="T_67276_row2_col3" class="data row2 col3" >0.2356</td>
#       <td id="T_67276_row2_col4" class="data row2 col4" >0.1196</td>
#       <td id="T_67276_row2_col5" class="data row2 col5" >0.1580</td>
#       <td id="T_67276_row2_col6" class="data row2 col6" >0.0509</td>
#       <td id="T_67276_row2_col7" class="data row2 col7" >0.0548</td>
#       <td id="T_67276_row2_col8" class="data row2 col8" >0.1640</td>
#     </tr>
#     <tr>
#       <th id="T_67276_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_67276_row3_col0" class="data row3 col0" >Ridge Classifier</td>
#       <td id="T_67276_row3_col1" class="data row3 col1" >0.7856</td>
#       <td id="T_67276_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_67276_row3_col3" class="data row3 col3" >0.2432</td>
#       <td id="T_67276_row3_col4" class="data row3 col4" >0.1223</td>
#       <td id="T_67276_row3_col5" class="data row3 col5" >0.1622</td>
#       <td id="T_67276_row3_col6" class="data row3 col6" >0.0551</td>
#       <td id="T_67276_row3_col7" class="data row3 col7" >0.0594</td>
#       <td id="T_67276_row3_col8" class="data row3 col8" >0.1240</td>
#     </tr>
#     <tr>
#       <th id="T_67276_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_67276_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_67276_row4_col1" class="data row4 col1" >0.7542</td>
#       <td id="T_67276_row4_col2" class="data row4 col2" >0.5615</td>
#       <td id="T_67276_row4_col3" class="data row4 col3" >0.3157</td>
#       <td id="T_67276_row4_col4" class="data row4 col4" >0.1260</td>
#       <td id="T_67276_row4_col5" class="data row4 col5" >0.1797</td>
#       <td id="T_67276_row4_col6" class="data row4 col6" >0.0659</td>
#       <td id="T_67276_row4_col7" class="data row4 col7" >0.0756</td>
#       <td id="T_67276_row4_col8" class="data row4 col8" >1.7040</td>
#     </tr>
#     <tr>
#       <th id="T_67276_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_67276_row5_col0" class="data row5 col0" >K Neighbors Classifier</td>
#       <td id="T_67276_row5_col1" class="data row5 col1" >0.6609</td>
#       <td id="T_67276_row5_col2" class="data row5 col2" >0.5662</td>
#       <td id="T_67276_row5_col3" class="data row5 col3" >0.4442</td>
#       <td id="T_67276_row5_col4" class="data row5 col4" >0.1154</td>
#       <td id="T_67276_row5_col5" class="data row5 col5" >0.1831</td>
#       <td id="T_67276_row5_col6" class="data row5 col6" >0.0551</td>
#       <td id="T_67276_row5_col7" class="data row5 col7" >0.0747</td>
#       <td id="T_6
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]

# %%
print(best_model)
# Out:
# QuadraticDiscriminantAnalysis(priors=None, reg_param=0.0,
#                               store_covariance=False, tol=0.0001)

# %%
dt = create_model('dt')
# Out:
# <style type="text/css">
# #T_ca4d3_row10_col0, #T_ca4d3_row10_col1, #T_ca4d3_row10_col2, #T_ca4d3_row10_col3, #T_ca4d3_row10_col4, #T_ca4d3_row10_col5, #T_ca4d3_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_ca4d3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca4d3_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_ca4d3_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_ca4d3_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_ca4d3_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_ca4d3_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_ca4d3_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_ca4d3_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca4d3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ca4d3_row0_col0" class="data row0 col0" >0.0954</td>
#       <td id="T_ca4d3_row0_col1" class="data row0 col1" >0.5056</td>
#       <td id="T_ca4d3_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_ca4d3_row0_col3" class="data row0 col3" >0.0859</td>
#       <td id="T_ca4d3_row0_col4" class="data row0 col4" >0.1583</td>
#       <td id="T_ca4d3_row0_col5" class="data row0 col5" >0.0019</td>
#       <td id="T_ca4d3_row0_col6" class="data row0 col6" >0.0311</td>
#     </tr>
#     <tr>
#       <th id="T_ca4d3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ca4d3_row1_col0" class="data row1 col0" >0.0979</td>
#       <td id="T_ca4d3_row1_col1" class="data row1 col1" >0.5070</td>
#       <td id="T_ca4d3_row1_col2" class="data row1 col2" >1.0000</td>
#       <td id="T_ca4d3_row1_col3" class="data row1 col3" >0.0862</td>
#       <td id="T_ca4d3_row1_col4" class="data row1 col4" >0.1587</td>
#       <td id="T_ca4d3_row1_col5" class="data row1 col5" >0.0024</td>
#       <td id="T_ca4d3_row1_col6" class="data row1 col6" >0.0348</td>
#     </tr>
#     <tr>
#       <th id="T_ca4d3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ca4d3_row2_col0" class="data row2 col0" >0.0941</td>
#       <td id="T_ca4d3_row2_col1" class="data row2 col1" >0.5049</td>
#       <td id="T_ca4d3_row2_col2" class="data row2 col2" >1.0000</td>
#       <td id="T_ca4d3_row2_col3" class="data row2 col3" >0.0858</td>
#       <td id="T_ca4d3_row2_col4" class="data row2 col4" >0.1581</td>
#       <td id="T_ca4d3_row2_col5" class="data row2 col5" >0.0017</td>
#       <td id="T_ca4d3_row2_col6" class="data row2 col6" >0.0291</td>
#     </tr>
#     <tr>
#       <th id="T_ca4d3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ca4d3_row3_col0" class="data row3 col0" >0.0902</td>
#       <td id="T_ca4d3_row3_col1" class="data row3 col1" >0.5028</td>
#       <td id="T_ca4d3_row3_col2" class="data row3 col2" >1.0000</td>
#       <td id="T_ca4d3_row3_col3" class="data row3 col3" >0.0855</td>
#       <td id="T_ca4d3_row3_col4" class="data row3 col4" >0.1575</td>
#       <td id="T_ca4d3_row3_col5" class="data row3 col5" >0.0010</td>
#       <td id="T_ca4d3_row3_col6" class="data row3 col6" >0.0219</td>
#     </tr>
#     <tr>
#       <th id="T_ca4d3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ca4d3_row4_col0" class="data row4 col0" >0.1095</td>
#       <td id="T_ca4d3_row4_col1" class="data row4 col1" >0.4996</td>
#       <td id="T_ca4d3_row4_col2" class="data row4 col2" >0.9697</td>
#       <td id="T_ca4d3_row4_col3" class="data row4 col3" >0.0850</td>
#       <td id="T_ca4d3_row4_col4" class="data row4 col4" >0.1563</td>
#       <td id="T_ca4d3_row4_col5" class="data row4 col5" >-0.0001</td>
#       <td id="T_ca4d3_row4_col6" class="data row4 col6" >-0.0012</td>
#     </tr>
#     <tr>
#       <th id="T_ca4d3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ca4d3_row5_col0" class="data row5 col0" >0.0889</td>
#       <td id="T_ca4d3_row5_col1" class="data row5 col1" >0.5021</td>
#       <td id="T_ca4d3_row5_col2" class="data row5 col2" >1.0000</td>
#       <td id="T_ca4d3_row5_col3" class="data row5 col3" >0.0854</td>
#       <td id="T_ca4d3_row5_col4" class="data row5 col4" >0.1573</td>
#       <td id="T_ca4d3_row5_col5" class="data row5 col5" >0.0007</td>
#       <td id="T_ca4d3_row5_col6" class="data row5 col6" >0.0190</td>
#     </tr>
#     <tr>
#       <th id="T_ca4d3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ca4d3_row6_col0" class="data row6 col0" >0.0928</td>
#       <td id="T_ca4d3_row6_col1" class="data row6 col1" >0.5035</td>
#       <td id="T_ca4d3_row6_col2" class="data row6 col2" >1.0000</td>
#       <td id="T_ca4d3_row6_col3" class="data row6 col3" >0.0869</td>
#       <td id="T_ca4d3_row6_col4" class="data row6 col4" >0.1599</td>
#       <td id="T_ca4d3_row6_col5" class="data row6 col5" >0.0012</td>
#       <td id="T_ca4d3_row6_col6" class="data row6 col6" >0.0248</td>
#     </tr>
#     <tr>
#       <th id="T_ca4d3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ca4d3_row7_col0" class="data row7 col0" >0.0863</td>
#       <td id="T_ca4d3_row7_col1" class="data row7 col1" >0.4932</td>
#       <td id="T_ca4d3_row7_col2" class="data row7 col2" >0.9851</td>
#       <td id="T_ca4d3_row7_col3" class="data row7 col3" >0.0853</td>
#       <td id="T_ca4d3_row7_col4" class="data row7 col4" >0.1570</td>
#       <td id="T_ca4d3_row7_col5" class="data row7 col5" >-0.0023</td>
#       <td id="T_ca4d3_row7_col6" class="data row7 col6" >-0.0749</td>
#     </tr>
#     <tr>
#       <th id="T_ca4d3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ca4d3_row8_col0" class="data row8 col0" >0.0968</td>
#       <td id="T_ca4d3_row8_col1" class="data row8 col1" >0.5063</td>
#       <td id="T_ca4d3_row8_col2" class="data row8 col2" >1.0000</td>
#       <td id="T_ca4d3_row8_col3" class="data row8 col3" >0.0862</td>
#       <td id="T_ca4d3_row8_col4" class="data row8 col4" >0.1587</td>
#       <td id="T_ca4d3_row8_col5" class="data row8 col5" >0.0022</td>
#       <td id="T_ca4d3_row8_col6" class="data row8 col6" >0.0331</td>
#     </tr>
#     <tr>
#       <th id="T_ca4d3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ca4d3_row9_col0" class="data row9 col0" >0.0890</td>
#       <td id="T_ca4d3_row9_col1" class="data row9 col1" >0.4952</td>
#       <td id="T_ca4d3_row9_col2" class="data row9 col2" >0.9848</td>
#       <td id="T_ca4d3_row9_col3" class="data row9 col3" >0.0844</td>
#       <td id="T_ca4d3_row9_col4" class="data row9 col4" >0.1555</td>
#       <td id="T_ca4d3_row9_col5" class="data row9 col5" >-0.0016</td>
#       <td id="T_ca4d3_row9_col6" class="data row9 col6" >-0.0332</td>
#     </tr>
#     <tr>
#       <th id="T_ca4d3_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_ca4d3_row10_col0" class="data row10 col0" >0.0941</td>
#       <td id="T_ca4d3_row10_col1" class="data row10 col1" >0.5021</td>
#       <td id="T_ca4d3_row10_col2" class="data row10 col2" >0.9940</td>
#       <td id="T_ca4d3_row10_col3" class="data row10 col3" >0.0857</td>
#       <td id="T_ca4d3_row10_col4" class="data row10 col4" >0.1577</td>
#       <td id="T_ca4d3_row10_col5" class="data row10 col5" >0.0007</td>
#       <td id="T_ca4d3_row10_col6" class="data row10 col6" >0.0085</td>
#     </tr>
#     <tr>
#       <th id="T_ca4d3_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_ca4d3_row11_col0" class="data row11 col0" >0.0063</td>
#       <td id="T_ca4d3_row11_col1" class="data row11 col1" >0.0044</td>
#       <td id="T_ca4d3_row11_col2" class="data row11 col2" >0.0100</td>
#       <td id="T_ca4d3_row11_col3" class="data row11 col3" >0.0007</td>
#       <td id="T_ca4d3_row1
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
print(dt)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        random_state=2564, splitter='best')

# %%
knn = create_model('knn')
# Out:
# <style type="text/css">
# #T_48c2c_row10_col0, #T_48c2c_row10_col1, #T_48c2c_row10_col2, #T_48c2c_row10_col3, #T_48c2c_row10_col4, #T_48c2c_row10_col5, #T_48c2c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_48c2c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_48c2c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_48c2c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_48c2c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_48c2c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_48c2c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_48c2c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_48c2c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48c2c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48c2c_row0_col0" class="data row0 col0" >0.6147</td>
#       <td id="T_48c2c_row0_col1" class="data row0 col1" >0.5837</td>
#       <td id="T_48c2c_row0_col2" class="data row0 col2" >0.5152</td>
#       <td id="T_48c2c_row0_col3" class="data row0 col3" >0.1130</td>
#       <td id="T_48c2c_row0_col4" class="data row0 col4" >0.1853</td>
#       <td id="T_48c2c_row0_col5" class="data row0 col5" >0.0532</td>
#       <td id="T_48c2c_row0_col6" class="data row0 col6" >0.0796</td>
#     </tr>
#     <tr>
#       <th id="T_48c2c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_48c2c_row1_col0" class="data row1 col0" >0.6353</td>
#       <td id="T_48c2c_row1_col1" class="data row1 col1" >0.5931</td>
#       <td id="T_48c2c_row1_col2" class="data row1 col2" >0.5152</td>
#       <td id="T_48c2c_row1_col3" class="data row1 col3" >0.1193</td>
#       <td id="T_48c2c_row1_col4" class="data row1 col4" >0.1937</td>
#       <td id="T_48c2c_row1_col5" class="data row1 col5" >0.0645</td>
#       <td id="T_48c2c_row1_col6" class="data row1 col6" >0.0935</td>
#     </tr>
#     <tr>
#       <th id="T_48c2c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_48c2c_row2_col0" class="data row2 col0" >0.6198</td>
#       <td id="T_48c2c_row2_col1" class="data row2 col1" >0.5206</td>
#       <td id="T_48c2c_row2_col2" class="data row2 col2" >0.3333</td>
#       <td id="T_48c2c_row2_col3" class="data row2 col3" >0.0806</td>
#       <td id="T_48c2c_row2_col4" class="data row2 col4" >0.1298</td>
#       <td id="T_48c2c_row2_col5" class="data row2 col5" >-0.0083</td>
#       <td id="T_48c2c_row2_col6" class="data row2 col6" >-0.0118</td>
#     </tr>
#     <tr>
#       <th id="T_48c2c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_48c2c_row3_col0" class="data row3 col0" >0.6160</td>
#       <td id="T_48c2c_row3_col1" class="data row3 col1" >0.5278</td>
#       <td id="T_48c2c_row3_col2" class="data row3 col2" >0.4545</td>
#       <td id="T_48c2c_row3_col3" class="data row3 col3" >0.1027</td>
#       <td id="T_48c2c_row3_col4" class="data row3 col4" >0.1676</td>
#       <td id="T_48c2c_row3_col5" class="data row3 col5" >0.0335</td>
#       <td id="T_48c2c_row3_col6" class="data row3 col6" >0.0493</td>
#     </tr>
#     <tr>
#       <th id="T_48c2c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_48c2c_row4_col0" class="data row4 col0" >0.6082</td>
#       <td id="T_48c2c_row4_col1" class="data row4 col1" >0.5144</td>
#       <td id="T_48c2c_row4_col2" class="data row4 col2" >0.4091</td>
#       <td id="T_48c2c_row4_col3" class="data row4 col3" >0.0925</td>
#       <td id="T_48c2c_row4_col4" class="data row4 col4" >0.1508</td>
#       <td id="T_48c2c_row4_col5" class="data row4 col5" >0.0140</td>
#       <td id="T_48c2c_row4_col6" class="data row4 col6" >0.0206</td>
#     </tr>
#     <tr>
#       <th id="T_48c2c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_48c2c_row5_col0" class="data row5 col0" >0.6186</td>
#       <td id="T_48c2c_row5_col1" class="data row5 col1" >0.5914</td>
#       <td id="T_48c2c_row5_col2" class="data row5 col2" >0.5152</td>
#       <td id="T_48c2c_row5_col3" class="data row5 col3" >0.1141</td>
#       <td id="T_48c2c_row5_col4" class="data row5 col4" >0.1868</td>
#       <td id="T_48c2c_row5_col5" class="data row5 col5" >0.0552</td>
#       <td id="T_48c2c_row5_col6" class="data row5 col6" >0.0822</td>
#     </tr>
#     <tr>
#       <th id="T_48c2c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_48c2c_row6_col0" class="data row6 col0" >0.6237</td>
#       <td id="T_48c2c_row6_col1" class="data row6 col1" >0.5506</td>
#       <td id="T_48c2c_row6_col2" class="data row6 col2" >0.4925</td>
#       <td id="T_48c2c_row6_col3" class="data row6 col3" >0.1134</td>
#       <td id="T_48c2c_row6_col4" class="data row6 col4" >0.1844</td>
#       <td id="T_48c2c_row6_col5" class="data row6 col5" >0.0512</td>
#       <td id="T_48c2c_row6_col6" class="data row6 col6" >0.0746</td>
#     </tr>
#     <tr>
#       <th id="T_48c2c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_48c2c_row7_col0" class="data row7 col0" >0.6649</td>
#       <td id="T_48c2c_row7_col1" class="data row7 col1" >0.6451</td>
#       <td id="T_48c2c_row7_col2" class="data row7 col2" >0.5821</td>
#       <td id="T_48c2c_row7_col3" class="data row7 col3" >0.1439</td>
#       <td id="T_48c2c_row7_col4" class="data row7 col4" >0.2308</td>
#       <td id="T_48c2c_row7_col5" class="data row7 col5" >0.1072</td>
#       <td id="T_48c2c_row7_col6" class="data row7 col6" >0.1502</td>
#     </tr>
#     <tr>
#       <th id="T_48c2c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_48c2c_row8_col0" class="data row8 col0" >0.6181</td>
#       <td id="T_48c2c_row8_col1" class="data row8 col1" >0.4888</td>
#       <td id="T_48c2c_row8_col2" class="data row8 col2" >0.3485</td>
#       <td id="T_48c2c_row8_col3" class="data row8 col3" >0.0833</td>
#       <td id="T_48c2c_row8_col4" class="data row8 col4" >0.1345</td>
#       <td id="T_48c2c_row8_col5" class="data row8 col5" >-0.0034</td>
#       <td id="T_48c2c_row8_col6" class="data row8 col6" >-0.0049</td>
#     </tr>
#     <tr>
#       <th id="T_48c2c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_48c2c_row9_col0" class="data row9 col0" >0.6181</td>
#       <td id="T_48c2c_row9_col1" class="data row9 col1" >0.5651</td>
#       <td id="T_48c2c_row9_col2" class="data row9 col2" >0.5000</td>
#       <td id="T_48c2c_row9_col3" class="data row9 col3" >0.1115</td>
#       <td id="T_48c2c_row9_col4" class="data row9 col4" >0.1823</td>
#       <td id="T_48c2c_row9_col5" class="data row9 col5" >0.0500</td>
#       <td id="T_48c2c_row9_col6" class="data row9 col6" >0.0741</td>
#     </tr>
#     <tr>
#       <th id="T_48c2c_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_48c2c_row10_col0" class="data row10 col0" >0.6237</td>
#       <td id="T_48c2c_row10_col1" class="data row10 col1" >0.5581</td>
#       <td id="T_48c2c_row10_col2" class="data row10 col2" >0.4666</td>
#       <td id="T_48c2c_row10_col3" class="data row10 col3" >0.1074</td>
#       <td id="T_48c2c_row10_col4" class="data row10 col4" >0.1746</td>
#       <td id="T_48c2c_row10_col5" class="data row10 col5" >0.0417</td>
#       <td id="T_48c2c_row10_col6" class="data row10 col6" >0.0608</td>
#     </tr>
#     <tr>
#       <th id="T_48c2c_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_48c2c_row11_col0" class="data row11 col0" >0.0152</td>
#       <td id="T_48c2c_row11_col1" class="data row11 col1" >0.0444</td>
#       <td id="T_48c2c_row11_col2" class="data row11 col2" >0.0757</td>
#       <td id="T_48c2c_row11_col3" class="data row11 col3" >0.0177</td>
#       <td id="T_48c2c_row11_
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
tuned_dt = tune_model(dt)
# Out:
# <style type="text/css">
# #T_310c9_row10_col0, #T_310c9_row10_col1, #T_310c9_row10_col2, #T_310c9_row10_col3, #T_310c9_row10_col4, #T_310c9_row10_col5, #T_310c9_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_310c9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_310c9_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_310c9_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_310c9_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_310c9_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_310c9_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_310c9_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_310c9_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_310c9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_310c9_row0_col0" class="data row0 col0" >0.9149</td>
#       <td id="T_310c9_row0_col1" class="data row0 col1" >0.5000</td>
#       <td id="T_310c9_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_310c9_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_310c9_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_310c9_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_310c9_row0_col6" class="data row0 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_310c9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_310c9_row1_col0" class="data row1 col0" >0.9149</td>
#       <td id="T_310c9_row1_col1" class="data row1 col1" >0.5000</td>
#       <td id="T_310c9_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_310c9_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_310c9_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_310c9_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_310c9_row1_col6" class="data row1 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_310c9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_310c9_row2_col0" class="data row2 col0" >0.9149</td>
#       <td id="T_310c9_row2_col1" class="data row2 col1" >0.5000</td>
#       <td id="T_310c9_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_310c9_row2_col3" class="data row2 col3" >0.0000</td>
#       <td id="T_310c9_row2_col4" class="data row2 col4" >0.0000</td>
#       <td id="T_310c9_row2_col5" class="data row2 col5" >0.0000</td>
#       <td id="T_310c9_row2_col6" class="data row2 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_310c9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_310c9_row3_col0" class="data row3 col0" >0.9149</td>
#       <td id="T_310c9_row3_col1" class="data row3 col1" >0.5000</td>
#       <td id="T_310c9_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_310c9_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_310c9_row3_col4" class="data row3 col4" >0.0000</td>
#       <td id="T_310c9_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_310c9_row3_col6" class="data row3 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_310c9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_310c9_row4_col0" class="data row4 col0" >0.9149</td>
#       <td id="T_310c9_row4_col1" class="data row4 col1" >0.5000</td>
#       <td id="T_310c9_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_310c9_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_310c9_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_310c9_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_310c9_row4_col6" class="data row4 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_310c9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_310c9_row5_col0" class="data row5 col0" >0.9149</td>
#       <td id="T_310c9_row5_col1" class="data row5 col1" >0.5000</td>
#       <td id="T_310c9_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_310c9_row5_col3" class="data row5 col3" >0.0000</td>
#       <td id="T_310c9_row5_col4" class="data row5 col4" >0.0000</td>
#       <td id="T_310c9_row5_col5" class="data row5 col5" >0.0000</td>
#       <td id="T_310c9_row5_col6" class="data row5 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_310c9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_310c9_row6_col0" class="data row6 col0" >0.9137</td>
#       <td id="T_310c9_row6_col1" class="data row6 col1" >0.5000</td>
#       <td id="T_310c9_row6_col2" class="data row6 col2" >0.0000</td>
#       <td id="T_310c9_row6_col3" class="data row6 col3" >0.0000</td>
#       <td id="T_310c9_row6_col4" class="data row6 col4" >0.0000</td>
#       <td id="T_310c9_row6_col5" class="data row6 col5" >0.0000</td>
#       <td id="T_310c9_row6_col6" class="data row6 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_310c9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_310c9_row7_col0" class="data row7 col0" >0.9137</td>
#       <td id="T_310c9_row7_col1" class="data row7 col1" >0.5000</td>
#       <td id="T_310c9_row7_col2" class="data row7 col2" >0.0000</td>
#       <td id="T_310c9_row7_col3" class="data row7 col3" >0.0000</td>
#       <td id="T_310c9_row7_col4" class="data row7 col4" >0.0000</td>
#       <td id="T_310c9_row7_col5" class="data row7 col5" >0.0000</td>
#       <td id="T_310c9_row7_col6" class="data row7 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_310c9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_310c9_row8_col0" class="data row8 col0" >0.9148</td>
#       <td id="T_310c9_row8_col1" class="data row8 col1" >0.5000</td>
#       <td id="T_310c9_row8_col2" class="data row8 col2" >0.0000</td>
#       <td id="T_310c9_row8_col3" class="data row8 col3" >0.0000</td>
#       <td id="T_310c9_row8_col4" class="data row8 col4" >0.0000</td>
#       <td id="T_310c9_row8_col5" class="data row8 col5" >0.0000</td>
#       <td id="T_310c9_row8_col6" class="data row8 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_310c9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_310c9_row9_col0" class="data row9 col0" >0.9148</td>
#       <td id="T_310c9_row9_col1" class="data row9 col1" >0.5000</td>
#       <td id="T_310c9_row9_col2" class="data row9 col2" >0.0000</td>
#       <td id="T_310c9_row9_col3" class="data row9 col3" >0.0000</td>
#       <td id="T_310c9_row9_col4" class="data row9 col4" >0.0000</td>
#       <td id="T_310c9_row9_col5" class="data row9 col5" >0.0000</td>
#       <td id="T_310c9_row9_col6" class="data row9 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_310c9_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_310c9_row10_col0" class="data row10 col0" >0.9147</td>
#       <td id="T_310c9_row10_col1" class="data row10 col1" >0.5000</td>
#       <td id="T_310c9_row10_col2" class="data row10 col2" >0.0000</td>
#       <td id="T_310c9_row10_col3" class="data row10 col3" >0.0000</td>
#       <td id="T_310c9_row10_col4" class="data row10 col4" >0.0000</td>
#       <td id="T_310c9_row10_col5" class="data row10 col5" >0.0000</td>
#       <td id="T_310c9_row10_col6" class="data row10 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_310c9_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_310c9_row11_col0" class="data row11 col0" >0.0005</td>
#       <td id="T_310c9_row11_col1" class="data row11 col1" >0.0000</td>
#       <td id="T_310c9_row11_col2" class="data row11 col2" >0.0000</td>
#       <td id="T_310c9_row11_col3" class="data row11 col3" >0.0000</td>
#       <td id="T_310c9_row11_col4
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
rf = create_model('rf')
# Out:
# <style type="text/css">
# #T_9dece_row10_col0, #T_9dece_row10_col1, #T_9dece_row10_col2, #T_9dece_row10_col3, #T_9dece_row10_col4, #T_9dece_row10_col5, #T_9dece_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9dece">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9dece_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9dece_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9dece_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9dece_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9dece_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9dece_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9dece_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9dece_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9dece_row0_col0" class="data row0 col0" >0.1302</td>
#       <td id="T_9dece_row0_col1" class="data row0 col1" >0.5738</td>
#       <td id="T_9dece_row0_col2" class="data row0 col2" >1.0000</td>
#       <td id="T_9dece_row0_col3" class="data row0 col3" >0.0891</td>
#       <td id="T_9dece_row0_col4" class="data row0 col4" >0.1636</td>
#       <td id="T_9dece_row0_col5" class="data row0 col5" >0.0087</td>
#       <td id="T_9dece_row0_col6" class="data row0 col6" >0.0663</td>
#     </tr>
#     <tr>
#       <th id="T_9dece_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9dece_row1_col0" class="data row1 col0" >0.1211</td>
#       <td id="T_9dece_row1_col1" class="data row1 col1" >0.5674</td>
#       <td id="T_9dece_row1_col2" class="data row1 col2" >0.9848</td>
#       <td id="T_9dece_row1_col3" class="data row1 col3" >0.0871</td>
#       <td id="T_9dece_row1_col4" class="data row1 col4" >0.1601</td>
#       <td id="T_9dece_row1_col5" class="data row1 col5" >0.0045</td>
#       <td id="T_9dece_row1_col6" class="data row1 col6" >0.0372</td>
#     </tr>
#     <tr>
#       <th id="T_9dece_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9dece_row2_col0" class="data row2 col0" >0.1302</td>
#       <td id="T_9dece_row2_col1" class="data row2 col1" >0.5262</td>
#       <td id="T_9dece_row2_col2" class="data row2 col2" >0.9545</td>
#       <td id="T_9dece_row2_col3" class="data row2 col3" >0.0857</td>
#       <td id="T_9dece_row2_col4" class="data row2 col4" >0.1573</td>
#       <td id="T_9dece_row2_col5" class="data row2 col5" >0.0014</td>
#       <td id="T_9dece_row2_col6" class="data row2 col6" >0.0101</td>
#     </tr>
#     <tr>
#       <th id="T_9dece_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9dece_row3_col0" class="data row3 col0" >0.1211</td>
#       <td id="T_9dece_row3_col1" class="data row3 col1" >0.5361</td>
#       <td id="T_9dece_row3_col2" class="data row3 col2" >0.9697</td>
#       <td id="T_9dece_row3_col3" class="data row3 col3" >0.0860</td>
#       <td id="T_9dece_row3_col4" class="data row3 col4" >0.1580</td>
#       <td id="T_9dece_row3_col5" class="data row3 col5" >0.0021</td>
#       <td id="T_9dece_row3_col6" class="data row3 col6" >0.0168</td>
#     </tr>
#     <tr>
#       <th id="T_9dece_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9dece_row4_col0" class="data row4 col0" >0.1276</td>
#       <td id="T_9dece_row4_col1" class="data row4 col1" >0.5269</td>
#       <td id="T_9dece_row4_col2" class="data row4 col2" >0.9697</td>
#       <td id="T_9dece_row4_col3" class="data row4 col3" >0.0866</td>
#       <td id="T_9dece_row4_col4" class="data row4 col4" >0.1590</td>
#       <td id="T_9dece_row4_col5" class="data row4 col5" >0.0034</td>
#       <td id="T_9dece_row4_col6" class="data row4 col6" >0.0249</td>
#     </tr>
#     <tr>
#       <th id="T_9dece_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9dece_row5_col0" class="data row5 col0" >0.1302</td>
#       <td id="T_9dece_row5_col1" class="data row5 col1" >0.5818</td>
#       <td id="T_9dece_row5_col2" class="data row5 col2" >0.9545</td>
#       <td id="T_9dece_row5_col3" class="data row5 col3" >0.0857</td>
#       <td id="T_9dece_row5_col4" class="data row5 col4" >0.1573</td>
#       <td id="T_9dece_row5_col5" class="data row5 col5" >0.0014</td>
#       <td id="T_9dece_row5_col6" class="data row5 col6" >0.0101</td>
#     </tr>
#     <tr>
#       <th id="T_9dece_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9dece_row6_col0" class="data row6 col0" >0.1250</td>
#       <td id="T_9dece_row6_col1" class="data row6 col1" >0.5435</td>
#       <td id="T_9dece_row6_col2" class="data row6 col2" >0.9851</td>
#       <td id="T_9dece_row6_col3" class="data row6 col3" >0.0887</td>
#       <td id="T_9dece_row6_col4" class="data row6 col4" >0.1628</td>
#       <td id="T_9dece_row6_col5" class="data row6 col5" >0.0052</td>
#       <td id="T_9dece_row6_col6" class="data row6 col6" >0.0407</td>
#     </tr>
#     <tr>
#       <th id="T_9dece_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9dece_row7_col0" class="data row7 col0" >0.1276</td>
#       <td id="T_9dece_row7_col1" class="data row7 col1" >0.6153</td>
#       <td id="T_9dece_row7_col2" class="data row7 col2" >0.9552</td>
#       <td id="T_9dece_row7_col3" class="data row7 col3" >0.0867</td>
#       <td id="T_9dece_row7_col4" class="data row7 col4" >0.1590</td>
#       <td id="T_9dece_row7_col5" class="data row7 col5" >0.0008</td>
#       <td id="T_9dece_row7_col6" class="data row7 col6" >0.0060</td>
#     </tr>
#     <tr>
#       <th id="T_9dece_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9dece_row8_col0" class="data row8 col0" >0.1394</td>
#       <td id="T_9dece_row8_col1" class="data row8 col1" >0.4950</td>
#       <td id="T_9dece_row8_col2" class="data row8 col2" >0.8939</td>
#       <td id="T_9dece_row8_col3" class="data row8 col3" >0.0821</td>
#       <td id="T_9dece_row8_col4" class="data row8 col4" >0.1503</td>
#       <td id="T_9dece_row8_col5" class="data row8 col5" >-0.0067</td>
#       <td id="T_9dece_row8_col6" class="data row8 col6" >-0.0398</td>
#     </tr>
#     <tr>
#       <th id="T_9dece_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9dece_row9_col0" class="data row9 col0" >0.1277</td>
#       <td id="T_9dece_row9_col1" class="data row9 col1" >0.5523</td>
#       <td id="T_9dece_row9_col2" class="data row9 col2" >0.9242</td>
#       <td id="T_9dece_row9_col3" class="data row9 col3" >0.0833</td>
#       <td id="T_9dece_row9_col4" class="data row9 col4" >0.1529</td>
#       <td id="T_9dece_row9_col5" class="data row9 col5" >-0.0040</td>
#       <td id="T_9dece_row9_col6" class="data row9 col6" >-0.0270</td>
#     </tr>
#     <tr>
#       <th id="T_9dece_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9dece_row10_col0" class="data row10 col0" >0.1280</td>
#       <td id="T_9dece_row10_col1" class="data row10 col1" >0.5518</td>
#       <td id="T_9dece_row10_col2" class="data row10 col2" >0.9592</td>
#       <td id="T_9dece_row10_col3" class="data row10 col3" >0.0861</td>
#       <td id="T_9dece_row10_col4" class="data row10 col4" >0.1580</td>
#       <td id="T_9dece_row10_col5" class="data row10 col5" >0.0017</td>
#       <td id="T_9dece_row10_col6" class="data row10 col6" >0.0145</td>
#     </tr>
#     <tr>
#       <th id="T_9dece_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_9dece_row11_col0" class="data row11 col0" >0.0050</td>
#       <td id="T_9dece_row11_col1" class="data row11 col1" >0.0324</td>
#       <td id="T_9dece_row11_col2" class="data row11 col2" >0.0296</td>
#       <td id="T_9dece_row11_col3" class="data row11 col3" >0.0020</td>
#       <td id="T_9dece_row11_
# Processing:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
tuned_rf = tune_model(rf, optimize='F1')
# Out:
# <style type="text/css">
# #T_0585e_row10_col0, #T_0585e_row10_col1, #T_0585e_row10_col2, #T_0585e_row10_col3, #T_0585e_row10_col4, #T_0585e_row10_col5, #T_0585e_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_0585e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0585e_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_0585e_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_0585e_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_0585e_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_0585e_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_0585e_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_0585e_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0585e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0585e_row0_col0" class="data row0 col0" >0.1263</td>
#       <td id="T_0585e_row0_col1" class="data row0 col1" >0.5241</td>
#       <td id="T_0585e_row0_col2" class="data row0 col2" >0.9848</td>
#       <td id="T_0585e_row0_col3" class="data row0 col3" >0.0876</td>
#       <td id="T_0585e_row0_col4" class="data row0 col4" >0.1609</td>
#       <td id="T_0585e_row0_col5" class="data row0 col5" >0.0055</td>
#       <td id="T_0585e_row0_col6" class="data row0 col6" >0.0427</td>
#     </tr>
#     <tr>
#       <th id="T_0585e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0585e_row1_col0" class="data row1 col0" >0.1160</td>
#       <td id="T_0585e_row1_col1" class="data row1 col1" >0.4904</td>
#       <td id="T_0585e_row1_col2" class="data row1 col2" >0.9697</td>
#       <td id="T_0585e_row1_col3" class="data row1 col3" >0.0856</td>
#       <td id="T_0585e_row1_col4" class="data row1 col4" >0.1572</td>
#       <td id="T_0585e_row1_col5" class="data row1 col5" >0.0011</td>
#       <td id="T_0585e_row1_col6" class="data row1 col6" >0.0094</td>
#     </tr>
#     <tr>
#       <th id="T_0585e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0585e_row2_col0" class="data row2 col0" >0.1392</td>
#       <td id="T_0585e_row2_col1" class="data row2 col1" >0.5157</td>
#       <td id="T_0585e_row2_col2" class="data row2 col2" >0.9697</td>
#       <td id="T_0585e_row2_col3" class="data row2 col3" >0.0877</td>
#       <td id="T_0585e_row2_col4" class="data row2 col4" >0.1608</td>
#       <td id="T_0585e_row2_col5" class="data row2 col5" >0.0057</td>
#       <td id="T_0585e_row2_col6" class="data row2 col6" >0.0374</td>
#     </tr>
#     <tr>
#       <th id="T_0585e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0585e_row3_col0" class="data row3 col0" >0.1237</td>
#       <td id="T_0585e_row3_col1" class="data row3 col1" >0.5200</td>
#       <td id="T_0585e_row3_col2" class="data row3 col2" >0.9697</td>
#       <td id="T_0585e_row3_col3" class="data row3 col3" >0.0863</td>
#       <td id="T_0585e_row3_col4" class="data row3 col4" >0.1584</td>
#       <td id="T_0585e_row3_col5" class="data row3 col5" >0.0026</td>
#       <td id="T_0585e_row3_col6" class="data row3 col6" >0.0201</td>
#     </tr>
#     <tr>
#       <th id="T_0585e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0585e_row4_col0" class="data row4 col0" >0.1366</td>
#       <td id="T_0585e_row4_col1" class="data row4 col1" >0.5091</td>
#       <td id="T_0585e_row4_col2" class="data row4 col2" >0.9697</td>
#       <td id="T_0585e_row4_col3" class="data row4 col3" >0.0874</td>
#       <td id="T_0585e_row4_col4" class="data row4 col4" >0.1604</td>
#       <td id="T_0585e_row4_col5" class="data row4 col5" >0.0052</td>
#       <td id="T_0585e_row4_col6" class="data row4 col6" >0.0348</td>
#     </tr>
#     <tr>
#       <th id="T_0585e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0585e_row5_col0" class="data row5 col0" >0.1392</td>
#       <td id="T_0585e_row5_col1" class="data row5 col1" >0.4697</td>
#       <td id="T_0585e_row5_col2" class="data row5 col2" >0.9545</td>
#       <td id="T_0585e_row5_col3" class="data row5 col3" >0.0865</td>
#       <td id="T_0585e_row5_col4" class="data row5 col4" >0.1587</td>
#       <td id="T_0585e_row5_col5" class="data row5 col5" >0.0032</td>
#       <td id="T_0585e_row5_col6" class="data row5 col6" >0.0208</td>
#     </tr>
#     <tr>
#       <th id="T_0585e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0585e_row6_col0" class="data row6 col0" >0.1289</td>
#       <td id="T_0585e_row6_col1" class="data row6 col1" >0.5057</td>
#       <td id="T_0585e_row6_col2" class="data row6 col2" >0.9552</td>
#       <td id="T_0585e_row6_col3" class="data row6 col3" >0.0868</td>
#       <td id="T_0585e_row6_col4" class="data row6 col4" >0.1592</td>
#       <td id="T_0585e_row6_col5" class="data row6 col5" >0.0011</td>
#       <td id="T_0585e_row6_col6" class="data row6 col6" >0.0077</td>
#     </tr>
#     <tr>
#       <th id="T_0585e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0585e_row7_col0" class="data row7 col0" >0.1443</td>
#       <td id="T_0585e_row7_col1" class="data row7 col1" >0.4958</td>
#       <td id="T_0585e_row7_col2" class="data row7 col2" >0.9552</td>
#       <td id="T_0585e_row7_col3" class="data row7 col3" >0.0883</td>
#       <td id="T_0585e_row7_col4" class="data row7 col4" >0.1616</td>
#       <td id="T_0585e_row7_col5" class="data row7 col5" >0.0042</td>
#       <td id="T_0585e_row7_col6" class="data row7 col6" >0.0260</td>
#     </tr>
#     <tr>
#       <th id="T_0585e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0585e_row8_col0" class="data row8 col0" >0.1290</td>
#       <td id="T_0585e_row8_col1" class="data row8 col1" >0.4903</td>
#       <td id="T_0585e_row8_col2" class="data row8 col2" >0.9697</td>
#       <td id="T_0585e_row8_col3" class="data row8 col3" >0.0868</td>
#       <td id="T_0585e_row8_col4" class="data row8 col4" >0.1594</td>
#       <td id="T_0585e_row8_col5" class="data row8 col5" >0.0036</td>
#       <td id="T_0585e_row8_col6" class="data row8 col6" >0.0265</td>
#     </tr>
#     <tr>
#       <th id="T_0585e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0585e_row9_col0" class="data row9 col0" >0.0852</td>
#       <td id="T_0585e_row9_col1" class="data row9 col1" >0.4776</td>
#       <td id="T_0585e_row9_col2" class="data row9 col2" >1.0000</td>
#       <td id="T_0585e_row9_col3" class="data row9 col3" >0.0852</td>
#       <td id="T_0585e_row9_col4" class="data row9 col4" >0.1570</td>
#       <td id="T_0585e_row9_col5" class="data row9 col5" >0.0000</td>
#       <td id="T_0585e_row9_col6" class="data row9 col6" >0.0000</td>
#     </tr>
#     <tr>
#       <th id="T_0585e_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_0585e_row10_col0" class="data row10 col0" >0.1268</td>
#       <td id="T_0585e_row10_col1" class="data row10 col1" >0.4998</td>
#       <td id="T_0585e_row10_col2" class="data row10 col2" >0.9698</td>
#       <td id="T_0585e_row10_col3" class="data row10 col3" >0.0868</td>
#       <td id="T_0585e_row10_col4" class="data row10 col4" >0.1594</td>
#       <td id="T_0585e_row10_col5" class="data row10 col5" >0.0032</td>
#       <td id="T_0585e_row10_col6" class="data row10 col6" >0.0225</td>
#     </tr>
#     <tr>
#       <th id="T_0585e_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_0585e_row11_col0" class="data row11 col0" >0.0161</td>
#       <td id="T_0585e_row11_col1" class="data row11 col1" >0.0172</td>
#       <td id="T_0585e_row11_col2" class="data row11 col2" >0.0134</td>
#       <td id="T_0585e_row11_col3" class="data row11 col3" >0.0009</td>
#       <td id="T_0585e_row11_col4
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
plot_model(tuned_rf, plot = 'pr')

# %%
plot_model(tuned_rf, plot='feature')

# %%
plot_model(tuned_rf, plot = 'confusion_matrix')

# %%
evaluate_model(tuned_rf)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
predict_model(tuned_rf);
# Out:
# <style type="text/css">
# </style>
# <table id="T_f6854">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f6854_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_f6854_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_f6854_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_f6854_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_f6854_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_f6854_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_f6854_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_f6854_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f6854_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f6854_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_f6854_row0_col1" class="data row0 col1" >0.1263</td>
#       <td id="T_f6854_row0_col2" class="data row0 col2" >0.4872</td>
#       <td id="T_f6854_row0_col3" class="data row0 col3" >0.9472</td>
#       <td id="T_f6854_row0_col4" class="data row0 col4" >0.0851</td>
#       <td id="T_f6854_row0_col5" class="data row0 col5" >0.1562</td>
#       <td id="T_f6854_row0_col6" class="data row0 col6" >-0.0006</td>
#       <td id="T_f6854_row0_col7" class="data row0 col7" >-0.0041</td>
#     </tr>
#   </tbody>
# </table>

# %%
final_rf = finalize_model(tuned_rf)

# %%
formula = '''
    mau ~  + qtd_filhos + idade + tempo_emprego +  
    qt_pessoas_residencia
'''

rl = smf.glm(formula, data=df1, family=sm.families.Binomial()).fit()

rl.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                       Generalized Linear Model Regression Results
# =======================================================================================
# Dep. Variable:     ['mau[False]', 'mau[True]']   No. Observations:                  400
# Model:                                     GLM   Df Residuals:                      395
# Model Family:                         Binomial   Df Model:                            4
# Link Function:                           Logit   Scale:                          1.0000
# Method:                                   IRLS   Log-Likelihood:                -114.79
# Date:                         Wed, 05 Oct 2022   Deviance:                       229.58
# Time:                                 10:47:26   Pearson chi2:                     392.
# No. Iterations:                              6   Pseudo R-squ. (CS):            0.03065
# Covariance Type:                     nonrobust
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -0.2160      1.076     -0.201      0.841      -2.324       1.892
# qtd_filhos               -0.9189      0.535     -1.716      0.086      -1.968       0.130
# idade                     0.0166      0.018      0.925      0.355      -0.019       0.052
# tempo_emprego             0.1011      0.046      2.199      0.028       0.011       0.191
# qt_pessoas_residencia     0.7172      0.421      1.704      0.088      -0.108       1.542
# =========================================================================================
# """

# %%
metadados.sort_values(by='IV', ascending=False)
# Out:
#                          dtype  nmissing  valores_unicos       papel        IV
# qt_pessoas_residencia  float64         0               9  covariavel       inf
# renda                  float64         0          112472  covariavel  0.959826
# tempo_emprego          float64         0            3005  covariavel  0.283956
# idade                    int64         0              47  covariavel  0.018434
# tipo_renda              object         0               5  covariavel  0.009718
# posse_de_imovel         object         0               2  covariavel  0.009690
# educacao                object         0               5  covariavel  0.003690
# tipo_residencia         object         0               6  covariavel  0.003330
# sexo                    object         0               2  covariavel  0.002665
# qtd_filhos               int64         0               8  covariavel  0.001689
# estado_civil            object         0               5  covariavel  0.001305
# posse_de_veiculo        object         0               2  covariavel  0.000075
# mau                      int64         0               2    resposta       NaN

# %%
import pickle

nome_arquivo = 'model_final.pkl'
pickle.dump(tuned_rf, open(nome_arquivo, 'wb'))
