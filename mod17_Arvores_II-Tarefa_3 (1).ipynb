# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Árvores II - Tarefa 3

# %% [markdown]
# ### 1. Carregar as bases
#
# Vamos utilizar nesta tarefa as bases de reconhecimento de atividade humana através do celular. Carregue novamente as bases salvas na tarefa I.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_confusion_matrix
from sklearn.model_selection import GridSearchCV

# %%
X_train = pd.read_csv('X_train_edit.csv', index_col = [0,1])
X_train.head(1)
# Out:
#            1 tBodyAcc-mean()-X  2 tBodyAcc-mean()-Y  3 tBodyAcc-mean()-Z  \
#   Subject
# 0 1                   0.288585            -0.020294            -0.132905
#
#            4 tBodyAcc-std()-X  5 tBodyAcc-std()-Y  6 tBodyAcc-std()-Z  \
#   Subject
# 0 1                 -0.995279           -0.983111           -0.913526
#
#            7 tBodyAcc-mad()-X  8 tBodyAcc-mad()-Y  9 tBodyAcc-mad()-Z  \
#   Subject
# 0 1                 -0.995112           -0.983185           -0.923527
#
#            10 tBodyAcc-max()-X  ...  552 fBodyBodyGyroJerkMag-meanFreq()  \
#   Subject                       ...
# 0 1                  -0.934724  ...                            -0.074323
#
#            553 fBodyBodyGyroJerkMag-skewness()  \
#   Subject
# 0 1                                  -0.298676
#
#            554 fBodyBodyGyroJerkMag-kurtosis()  \
#   Subject
# 0 1                                  -0.710304
#
#            555 angle(tBodyAccMean,gravity)  \
#   Subject
# 0 1                              -0.112754
#
#            556 angle(tBodyAccJerkMean),gravityMean)  \
#   Subject
# 0 1                                          0.0304
#
#            557 angle(tBodyGyroMean,gravityMean)  \
#   Subject
# 0 1                                   -0.464761
#
#            558 angle(tBodyGyroJerkMean,gravityMean)  559 angle(X,gravityMean)  \
#   Subject
# 0 1                                       -0.018446                 -0.841247
#
#            560 angle(Y,gravityMean)  561 angle(Z,gravityMean)
#   Subject
# 0 1                        0.179941                 -0.058627
#
# [1 rows x 561 columns]

# %%
X_test = pd.read_csv('X_test_edit.csv', index_col = [0,1])
X_test.head(1)
# Out:
#            1 tBodyAcc-mean()-X  2 tBodyAcc-mean()-Y  3 tBodyAcc-mean()-Z  \
#   Subject
# 0 2                   0.257178            -0.023285            -0.014654
#
#            4 tBodyAcc-std()-X  5 tBodyAcc-std()-Y  6 tBodyAcc-std()-Z  \
#   Subject
# 0 2                 -0.938404           -0.920091           -0.667683
#
#            7 tBodyAcc-mad()-X  8 tBodyAcc-mad()-Y  9 tBodyAcc-mad()-Z  \
#   Subject
# 0 2                 -0.952501           -0.925249           -0.674302
#
#            10 tBodyAcc-max()-X  ...  552 fBodyBodyGyroJerkMag-meanFreq()  \
#   Subject                       ...
# 0 2                  -0.894088  ...                             0.071645
#
#            553 fBodyBodyGyroJerkMag-skewness()  \
#   Subject
# 0 2                                   -0.33037
#
#            554 fBodyBodyGyroJerkMag-kurtosis()  \
#   Subject
# 0 2                                  -0.705974
#
#            555 angle(tBodyAccMean,gravity)  \
#   Subject
# 0 2                               0.006462
#
#            556 angle(tBodyAccJerkMean),gravityMean)  \
#   Subject
# 0 2                                         0.16292
#
#            557 angle(tBodyGyroMean,gravityMean)  \
#   Subject
# 0 2                                   -0.825886
#
#            558 angle(tBodyGyroJerkMean,gravityMean)  559 angle(X,gravityMean)  \
#   Subject
# 0 2                                        0.271151                 -0.720009
#
#            560 angle(Y,gravityMean)  561 angle(Z,gravityMean)
#   Subject
# 0 2                        0.276801                 -0.057978
#
# [1 rows x 561 columns]

# %%
y_train = pd.read_csv('y_train_edit.csv', index_col = [0,1])
y_train.head(1)
# Out:
#            0
#   Subject
# 0 1        5

# %%
y_test = pd.read_csv('y_test_edit.csv', index_col = [0,1])
y_test.head(1)
# Out:
#            0
#   Subject
# 0 2        5

# %% [markdown]
# ### 2. Calcule os ```ccp_alphas```.
#
# Vamos seguir uma lógica bem em linha com o que já estamso acostumados, com as seguintes orientações:
#
# - Utilizar treinamento e teste conforme já vieram definidos originalmente
# - Por pragmatismo, utilizar ```min_samples_leaf=20```
# - Utilize as mesmas "3 melhores variáveis" identificadas no exercício anterior.

# %%
X_train_cut = X_train[['53 tGravityAcc-min()-X','382 fBodyAccJerk-bandsEnergy()-1,8','560 angle(Y,gravityMean)']]
X_test_cut = X_test[['53 tGravityAcc-min()-X','382 fBodyAccJerk-bandsEnergy()-1,8','560 angle(Y,gravityMean)']]

# %%
path = DecisionTreeClassifier(random_state=100, min_samples_leaf = 20).cost_complexity_pruning_path(X_train_cut, y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities
ccp_alphas
# Out:
# array([0.00000000e+00, 6.59906426e-06, 6.80087051e-06, 8.99098135e-06,
#        9.35119695e-06, 9.89217529e-06, 1.08258755e-05, 1.10353748e-05,
#        1.75427739e-05, 2.38241675e-05, 3.18341304e-05, 3.69307877e-05,
#        4.07553476e-05, 4.18602847e-05, 5.26532445e-05, 5.55018995e-05,
#        5.87197700e-05, 6.41224934e-05, 7.20748845e-05, 7.29725943e-05,
#        7.34494015e-05, 8.56481444e-05, 8.61634436e-05, 8.84113166e-05,
#        8.89002681e-05, 9.39016923e-05, 9.85135044e-05, 9.93339269e-05,
#        1.08353426e-04, 1.12003796e-04, 1.12102261e-04, 1.16839113e-04,
#        1.22582202e-04, 1.47025120e-04, 1.47143607e-04, 1.50665439e-04,
#        1.53540577e-04, 1.74596286e-04, 2.11065827e-04, 2.20689051e-04,
#        2.27768134e-04, 2.38088595e-04, 2.49550310e-04, 2.85636561e-04,
#        2.88026156e-04, 2.89776222e-04, 2.97189102e-04, 3.50665838e-04,
#        3.60123931e-04, 3.62028531e-04, 3.66010486e-04, 4.35255713e-04,
#        4.35809630e-04, 4.43756801e-04, 4.45010651e-04, 4.49597283e-04,
#        4.63903615e-04, 4.92577336e-04, 5.18922656e-04, 5.39637745e-04,
#        5.50766401e-04, 5.55314481e-04, 5.88131369e-04, 5.99482898e-04,
#        6.01651234e-04, 6.21251573e-04, 6.71101695e-04, 7.72176228e-04,
#        8.60275568e-04, 8.66880627e-04, 8.89427640e-04, 9.60757029e-04,
#        1.01142779e-03, 1.02621026e-03, 1.05610742e-03, 1.06036006e-03,
#        1.07142910e-03, 1.09014169e-03, 1.17065479e-03, 1.29237613e-03,
#        1.42753784e-03, 1.43694583e-03, 1.48587311e-03, 1.48774199e-03,
#        1.57549975e-03, 1.62275834e-03, 1.65183193e-03, 2.06027725e-03,
#        2.10690875e-03, 2.14503989e-03, 2.16385984e-03, 2.17446951e-03,
#        2.64718029e-03, 3.85537620e-03, 3.98823625e-03, 4.38907334e-03,
#        4.63559121e-03, 5.27362619e-03, 6.90029361e-03, 1.01140941e-02,
#        1.03430703e-02, 4.35253433e-02, 6.52814468e-02, 1.09296113e-01,
#        1.67148656e-01, 1.86138242e-01])

# %% [markdown]
# ### 3. *Grid Search*
#
# Vou deixar especificações iniciais mínimas, que visam limitar o tempo de máquina, pois um procedimento desses pode demorar muito tempo dependendo da especificação. Mas conforme você for ficando confortável com o tempo consumido pelo procedimento, pode fazer um algoritmo mais exaustivo, por exemplo, avaliando mais valores de ```ccp_alpha```.
#
# - Meça o tempo
# - Utilize a base de treinamento
# - Utilize um *cross validation* do tipo *k-fold*, especifique k=10
# - Você pode ler 1 a cada ```k``` valores para uma melhor varredura utilizando, por exemplo, ```ccp_alpha[::10]```
# - Não se esqueça de limitar o número de variáveis

# %%
clf = DecisionTreeClassifier(random_state=100, min_samples_leaf = 20).fit(X_train_cut, y_train)

# %%
grid_parametros = {'ccp_alpha':ccp_alphas[::5]}
grid_parametros
# Out:
# {'ccp_alpha': array([0.00000000e+00, 9.89217529e-06, 3.18341304e-05, 5.55018995e-05,
#         7.34494015e-05, 9.39016923e-05, 1.12102261e-04, 1.50665439e-04,
#         2.27768134e-04, 2.89776222e-04, 3.66010486e-04, 4.49597283e-04,
#         5.50766401e-04, 6.21251573e-04, 8.89427640e-04, 1.06036006e-03,
#         1.42753784e-03, 1.62275834e-03, 2.16385984e-03, 4.38907334e-03,
#         1.03430703e-02, 1.86138242e-01])}

# %%
# %%time

grid = GridSearchCV(estimator = clf, param_grid=grid_parametros,cv=10)
grid.fit(X_train_cut, y_train)
# Out:
# CPU times: total: 3.75 s
# Wall time: 3.76 s
# GridSearchCV(cv=10,
#              estimator=DecisionTreeClassifier(min_samples_leaf=20,
#                                               random_state=100),
#              param_grid={'ccp_alpha': array([0.00000000e+00, 9.89217529e-06, 3.18341304e-05, 5.55018995e-05,
#        7.34494015e-05, 9.39016923e-05, 1.12102261e-04, 1.50665439e-04,
#        2.27768134e-04, 2.89776222e-04, 3.66010486e-04, 4.49597283e-04,
#        5.50766401e-04, 6.21251573e-04, 8.89427640e-04, 1.06036006e-03,
#        1.42753784e-03, 1.62275834e-03, 2.16385984e-03, 4.38907334e-03,
#        1.03430703e-02, 1.86138242e-01])})

# %%
resultados = pd.DataFrame(grid.cv_results_)
resultados.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.015064      0.002082         0.000401        0.000668
# 1       0.015622      0.000002         0.001561        0.004684
# 2       0.017183      0.004687         0.000000        0.000000
# 3       0.015622      0.000003         0.001562        0.004686
# 4       0.015621      0.000002         0.001562        0.004687
#
#   param_ccp_alpha                                params  split0_test_score  \
# 0             0.0                    {'ccp_alpha': 0.0}           0.739130
# 1         0.00001  {'ccp_alpha': 9.892175289345545e-06}           0.739130
# 2        0.000032  {'ccp_alpha': 3.183413042732075e-05}           0.739130
# 3        0.000056  {'ccp_alpha': 5.550189952419353e-05}           0.748641
# 4        0.000073  {'ccp_alpha': 7.344940152339511e-05}           0.748641
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.797554           0.808163           0.727891           0.783673
# 1           0.797554           0.808163           0.727891           0.783673
# 2           0.797554           0.808163           0.727891           0.783673
# 3           0.797554           0.808163           0.727891           0.783673
# 4           0.797554           0.808163           0.727891           0.783673
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 0           0.717007           0.764626           0.697959           0.854422
# 1           0.717007           0.764626           0.697959           0.854422
# 2           0.717007           0.764626           0.697959           0.854422
# 3           0.717007           0.764626           0.697959           0.854422
# 4           0.717007           0.764626           0.697959           0.854422
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.790476         0.768090        0.045459               18
# 1           0.790476         0.768090        0.045459               18
# 2           0.790476         0.768090        0.045459               18
# 3           0.790476         0.769041        0.044940               12
# 4           0.790476         0.769041        0.044940               12

# %%
grid.best_score_
# Out:
# 0.8023593241644484

# %%
melhor_ccp = resultados.iloc[grid.best_index_,4]
melhor_ccp
# Out:
# 0.004389073344928773

# %% [markdown]
# ### 4. Avaliando a árvore
#
# - Obtenha a árvore na melhor configuração treinada em toda a base de treino
# - Calcule a acurácia dessa árvore na base de testes
# - Visualize a matriz de confusão

# %%
clf = DecisionTreeClassifier(random_state=100, ccp_alpha=melhor_ccp).fit(X_train_cut, y_train)

# %%
clf.score(X_test_cut, y_test)
# Out:
# 0.7376993552765524

# %%
plot_confusion_matrix(clf, X_test_cut, y_test);
# Out:
# C:\Users\Fernanda\anaconda3\Nova pasta\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ### 5. Melhorando a árvore
#
# A melhor forma de se melhorar um algoritmo é colocando nele novas variáveis que agreguem valor. Podemos usar a força-bruta e ir colocando variáveis aleatoriamente - ou colocar todas e deixar rodando por um bom tempo - ou utilizar uma lógica eficiente e fazer uma seleção de variáveis.
#
# - Observe que há classes mais fáceis e mais difíceis de se identificar
# - Crie uma variável binária para uma das classes de maior erro
# - Fala uma árvore de classificação bem simples para esta variável:
#     - utilize ```mean_samples_leaf=20```
#     - utilize ```max_depth=4```
#     - coloque todas as variáveis
# - Observe a importância das variáveis, e selecione as 3 com maior importância
# - Rode novamente o algoritmo acima com as 3 novas variáveis e avalie a acurácia

# %%
y_train_dummies = pd.get_dummies(y_train['0'])
y_train_cut = y_train_dummies[2].to_frame()
y_train_cut.head(1)
# Out:
#            2
#   Subject
# 0 1        0

# %%
clf = DecisionTreeClassifier(random_state=100, min_samples_leaf = 20, max_depth = 4).fit(X_train, y_train_cut)

# %%
importancia = pd.Series(clf.feature_importances_, index = X_train.columns)
importancia.sort_values(ascending = False, inplace = True)
importancia.head(3)
# Out:
# 74 tGravityAcc-arCoeff()-Z,1      0.336087
# 331 fBodyAcc-bandsEnergy()-1,8    0.308642
# 440 fBodyGyro-energy()-X          0.066982
# dtype: float64

# %%
X_train_cut = X_train[['74 tGravityAcc-arCoeff()-Z,1','331 fBodyAcc-bandsEnergy()-1,8','440 fBodyGyro-energy()-X']]
X_test_cut = X_test[['74 tGravityAcc-arCoeff()-Z,1','331 fBodyAcc-bandsEnergy()-1,8','440 fBodyGyro-energy()-X']]

# %%
path = DecisionTreeClassifier(random_state=100, min_samples_leaf = 20).cost_complexity_pruning_path(X_train_cut, y_train)
ccp_alphas, impurities = path.ccp_alphas, path.impurities
ccp_alphas
# Out:
# array([0.00000000e+00, 6.26536890e-06, 7.68794058e-06, 8.26772494e-06,
#        9.97344437e-06, 1.62755875e-05, 2.07470146e-05, 2.85462788e-05,
#        3.05715322e-05, 3.24166929e-05, 3.74826031e-05, 4.02752851e-05,
#        4.34459928e-05, 4.62738549e-05, 4.84884134e-05, 5.09274489e-05,
#        5.11378301e-05, 5.88072250e-05, 6.12078346e-05, 6.22971515e-05,
#        6.65955372e-05, 6.85854055e-05, 6.95695110e-05, 7.19893734e-05,
#        7.21725034e-05, 7.25584164e-05, 7.31946532e-05, 7.84100365e-05,
#        7.88129249e-05, 7.93059746e-05, 8.08880966e-05, 8.10854901e-05,
#        8.21992661e-05, 8.53544794e-05, 8.78297929e-05, 8.84113166e-05,
#        8.84113166e-05, 8.91384798e-05, 9.04427455e-05, 9.47032840e-05,
#        9.79109453e-05, 9.89670749e-05, 9.99969893e-05, 1.02811645e-04,
#        1.05553741e-04, 1.05680132e-04, 1.06544679e-04, 1.12362208e-04,
#        1.13288960e-04, 1.21944613e-04, 1.22595984e-04, 1.30608850e-04,
#        1.31250988e-04, 1.35276796e-04, 1.39401069e-04, 1.40508874e-04,
#        1.41629317e-04, 1.42364889e-04, 1.42818281e-04, 1.48639700e-04,
#        1.49619151e-04, 1.50864732e-04, 1.53529695e-04, 1.53575213e-04,
#        1.53613313e-04, 1.58197632e-04, 1.60353136e-04, 1.60451222e-04,
#        1.62414710e-04, 1.64127675e-04, 1.64487874e-04, 1.65251084e-04,
#        1.65528290e-04, 1.65582293e-04, 1.65907756e-04, 1.66769461e-04,
#        1.68240582e-04, 1.75649188e-04, 1.79618032e-04, 1.79795896e-04,
#        1.80614059e-04, 1.80882931e-04, 1.82263330e-04, 1.88780254e-04,
#        1.92540201e-04, 1.93388893e-04, 1.95713940e-04, 1.96111309e-04,
#        1.96469012e-04, 2.00508723e-04, 2.01836332e-04, 2.04134066e-04,
#        2.09978906e-04, 2.22148010e-04, 2.24841442e-04, 2.25247000e-04,
#        2.29405140e-04, 2.29577177e-04, 2.30743821e-04, 2.33307641e-04,
#        2.37164483e-04, 2.41153191e-04, 2.42921087e-04, 2.43563662e-04,
#        2.44831338e-04, 2.47832804e-04, 2.54941372e-04, 2.57253751e-04,
#        2.57596685e-04, 2.61423533e-04, 2.62166891e-04, 2.64710132e-04,
#        2.73717241e-04, 2.79323787e-04, 2.81035508e-04, 2.81973821e-04,
#        2.82751344e-04, 2.89046237e-04, 2.89453411e-04, 2.90426627e-04,
#        2.95384881e-04, 3.09931927e-04, 3.10618072e-04, 3.10949060e-04,
#        3.14540327e-04, 3.22370026e-04, 3.23904797e-04, 3.25630853e-04,
#        3.29633304e-04, 3.29872409e-04, 3.35446980e-04, 3.36426583e-04,
#        3.40024519e-04, 3.50924918e-04, 3.51487415e-04, 3.51825864e-04,
#        3.62113017e-04, 3.66800379e-04, 3.76014731e-04, 3.80873508e-04,
#        3.81021971e-04, 3.94608466e-04, 4.04866347e-04, 4.09203674e-04,
#        4.10296994e-04, 4.12807753e-04, 4.20243342e-04, 4.22808205e-04,
#        4.26218829e-04, 4.27401128e-04, 4.40802897e-04, 4.41673132e-04,
#        4.46000777e-04, 4.50113889e-04, 4.63695717e-04, 4.68711990e-04,
#        4.83333077e-04, 4.91681734e-04, 5.52025342e-04, 5.52081206e-04,
#        5.64016987e-04, 5.75980674e-04, 5.85581929e-04, 6.21546019e-04,
#        6.35236979e-04, 6.55804069e-04, 6.79344674e-04, 6.88160905e-04,
#        6.88978024e-04, 6.89529312e-04, 7.30446294e-04, 7.34855669e-04,
#        7.56600614e-04, 7.61697497e-04, 7.73852436e-04, 7.83993280e-04,
#        7.93987809e-04, 8.22693093e-04, 8.25035367e-04, 8.34663263e-04,
#        9.00399367e-04, 1.01826918e-03, 1.02727874e-03, 1.06669384e-03,
#        1.11240824e-03, 1.11381666e-03, 1.22976810e-03, 1.23031730e-03,
#        1.23100619e-03, 1.24585729e-03, 1.46487641e-03, 1.52261703e-03,
#        1.55679263e-03, 1.80930764e-03, 2.40521301e-03, 2.47465690e-03,
#        2.70373762e-03, 3.08525629e-03, 3.50149586e-03, 3.56658388e-03,
#        3.58993200e-03, 4.67899349e-03, 4.80229946e-03, 5.65950762e-03,
#        9.43307307e-03, 1.15097969e-02, 1.62500766e-02, 1.89088968e-02,
#        7.40162052e-02, 1.59365746e-01])

# %%
clf = DecisionTreeClassifier(random_state=100, min_samples_leaf = 20).fit(X_train_cut, y_train)

# %%
grid_parametros = {'ccp_alpha':ccp_alphas[::5]}
grid_parametros
# Out:
# {'ccp_alpha': array([0.00000000e+00, 1.62755875e-05, 3.74826031e-05, 5.09274489e-05,
#         6.65955372e-05, 7.25584164e-05, 8.08880966e-05, 8.84113166e-05,
#         9.79109453e-05, 1.05680132e-04, 1.22595984e-04, 1.40508874e-04,
#         1.49619151e-04, 1.58197632e-04, 1.64487874e-04, 1.66769461e-04,
#         1.80614059e-04, 1.93388893e-04, 2.01836332e-04, 2.25247000e-04,
#         2.37164483e-04, 2.47832804e-04, 2.62166891e-04, 2.81973821e-04,
#         2.95384881e-04, 3.22370026e-04, 3.35446980e-04, 3.51825864e-04,
#         3.81021971e-04, 4.12807753e-04, 4.40802897e-04, 4.68711990e-04,
#         5.64016987e-04, 6.55804069e-04, 7.30446294e-04, 7.83993280e-04,
#         9.00399367e-04, 1.11381666e-03, 1.46487641e-03, 2.47465690e-03,
#         3.58993200e-03, 1.15097969e-02])}

# %%
# %%time

grid = GridSearchCV(estimator = clf, param_grid=grid_parametros,cv=10)
grid.fit(X_train_cut, y_train)
# Out:
# CPU times: total: 9.3 s
# Wall time: 9.32 s
# GridSearchCV(cv=10,
#              estimator=DecisionTreeClassifier(min_samples_leaf=20,
#                                               random_state=100),
#              param_grid={'ccp_alpha': array([0.00000000e+00, 1.62755875e-05, 3.74826031e-05, 5.09274489e-05,
#        6.65955372e-05, 7.25584164e-05, 8.08880966e-05, 8.84113166e-05,
#        9.79109453e-05, 1.05680132e-04, 1.22595984e-04, 1.40508874e-04,
#        1.49619151e-04, 1.58197632e-04, 1.64487874e-04, 1.66...
#        1.80614059e-04, 1.93388893e-04, 2.01836332e-04, 2.25247000e-04,
#        2.37164483e-04, 2.47832804e-04, 2.62166891e-04, 2.81973821e-04,
#        2.95384881e-04, 3.22370026e-04, 3.35446980e-04, 3.51825864e-04,
#        3.81021971e-04, 4.12807753e-04, 4.40802897e-04, 4.68711990e-04,
#        5.64016987e-04, 6.55804069e-04, 7.30446294e-04, 7.83993280e-04,
#        9.00399367e-04, 1.11381666e-03, 1.46487641e-03, 2.47465690e-03,
#        3.58993200e-03, 1.15097969e-02])})

# %%
resultados = pd.DataFrame(grid.cv_results_)
resultados.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.018667      0.005108         0.001860        0.004608
# 1       0.021233      0.007484         0.001861        0.004629
# 2       0.019427      0.006065         0.001661        0.004662
# 3       0.019683      0.007032         0.001661        0.004663
# 4       0.021098      0.006068         0.000642        0.000699
#
#   param_ccp_alpha                                 params  split0_test_score  \
# 0             0.0                     {'ccp_alpha': 0.0}           0.557065
# 1        0.000016  {'ccp_alpha': 1.6275587548709937e-05}           0.557065
# 2        0.000037   {'ccp_alpha': 3.748260312197308e-05}           0.557065
# 3        0.000051   {'ccp_alpha': 5.092744894602281e-05}           0.557065
# 4        0.000067    {'ccp_alpha': 6.65955372157771e-05}           0.557065
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0           0.444293           0.512925           0.522449            0.52517
# 1           0.444293           0.512925           0.522449            0.52517
# 2           0.444293           0.512925           0.521088            0.52517
# 3           0.444293           0.512925           0.521088            0.52517
# 4           0.444293           0.512925           0.521088            0.52517
#
#    split5_test_score  split6_test_score  split7_test_score  split8_test_score  \
# 0           0.495238           0.571429           0.623129           0.598639
# 1           0.495238           0.571429           0.623129           0.598639
# 2           0.495238           0.571429           0.623129           0.598639
# 3           0.495238           0.571429           0.623129           0.598639
# 4           0.492517           0.571429           0.621769           0.597279
#
#    split9_test_score  mean_test_score  std_test_score  rank_test_score
# 0           0.610884         0.546122        0.053574               32
# 1           0.610884         0.546122        0.053574               32
# 2           0.610884         0.545986        0.053636               35
# 3           0.610884         0.545986        0.053636               35
# 4           0.610884         0.545442        0.053572               38

# %%
grid.best_score_
# Out:
# 0.5944036527654541

# %%
melhor_ccp = resultados.iloc[grid.best_index_,4]
melhor_ccp
# Out:
# 0.002474656903782596

# %%
clf = DecisionTreeClassifier(random_state=100, ccp_alpha=melhor_ccp).fit(X_train_cut, y_train)

# %%
clf.score(X_test_cut, y_test)
# Out:
# 0.5839837122497455

# %%
plot_confusion_matrix(clf, X_test_cut, y_test);
# Out:
# C:\Users\Fernanda\anaconda3\Nova pasta\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_confusion_matrix is deprecated; Function `plot_confusion_matrix` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: ConfusionMatrixDisplay.from_predictions or ConfusionMatrixDisplay.from_estimator.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# - Acurácia anterior apenas da classe 2: 249/(217+249+5) = 52,87%
# - Acurácia depois apenas da classe 2: 308/(139+308+13+11) = 65,39%

# %% [markdown]
# <span style="color:blue">- Apesar do modelo anterior possuir acurácia geral maior do que o modelo atual, se desejarmos um modelo apenas para a classe 2 este último acaba sendo melhor que o anterior.</span>
